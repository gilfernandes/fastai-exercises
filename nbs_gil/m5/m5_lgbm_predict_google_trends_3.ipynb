# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
from datetime import datetime, timedelta
import gc
import numpy as np, pandas as pd
import lightgbm as lgb
from pathlib import Path

# %%
from fastai.vision import *

# %%
pd.options.display.max_columns = 50

# %% [markdown]
# ## Setup the path

# %%
path = Path('/kaggle/m5_forecasting/')
assert(path.exists())

# %%
def ls(self):
    return list(self.iterdir())
setattr(Path, 'ls', ls)

# %%
path.ls()
# Out:
# [PosixPath('/kaggle/m5_forecasting/sales_train_validation.csv'),
#  PosixPath('/kaggle/m5_forecasting/walmartTrends0.csv'),
#  PosixPath('/kaggle/m5_forecasting/m5_model.lgb'),
#  PosixPath('/kaggle/m5_forecasting/calendar.csv'),
#  PosixPath('/kaggle/m5_forecasting/sample_submission.csv'),
#  PosixPath('/kaggle/m5_forecasting/sell_prices.csv')]

# %% [markdown]
# ## Read Data

# %%
PRICE_DTYPES = {"store_id": "category", "item_id": "category", "wm_yr_wk": "int16","sell_price":"float32" }
CAL_DTYPES = {"event_name_1": "category", "event_name_2": "category", "event_type_1": "category", 
         "event_type_2": "category", "weekday": "category", 'wm_yr_wk': 'int16', "wday": "int16",
        "month": "int16", "year": "int16", "snap_CA": "float32", 'snap_TX': 'float32', 'snap_WI': 'float32' }

# %%
sales_train_validation = pd.read_csv(path/"sales_train_validation.csv", nrows=10)

# %%
def read_data():
    prices = pd.read_csv(path/"sell_prices.csv", dtype = PRICE_DTYPES)
    cal = pd.read_csv(path/"calendar.csv", dtype = CAL_DTYPES)
    walmart_trends = pd.read_csv(path/"walmartTrends0.csv")
    return prices, cal, walmart_trends

# %%
prices, cal, walmart_trends = read_data()

# %%
cal.head()
# Out:
#          date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011  d_1          NaN
# 1  2011-01-30     11101     Sunday     2      1  2011  d_2          NaN
# 2  2011-01-31     11101     Monday     3      1  2011  d_3          NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011  d_4          NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN      0.0      0.0      0.0
# 1          NaN          NaN          NaN      0.0      0.0      0.0
# 2          NaN          NaN          NaN      0.0      0.0      0.0
# 3          NaN          NaN          NaN      1.0      1.0      0.0
# 4          NaN          NaN          NaN      1.0      0.0      1.0

# %% [markdown]
# #### Pre-process Walmart

# %%
walmart_trends.reset_index(inplace=True)
del walmart_trends['index']
walmart_trends.columns
# Out:
# Index(['Week', 'Walmart: (United States)'], dtype='object')

# %%
walmart_trends["date"] = pd.to_datetime(walmart_trends["Week"], infer_datetime_format=True)

# %%
del walmart_trends['Week']
walmart_trends.columns
# Out:
# Index(['Walmart: (United States)', 'date'], dtype='object')

# %%
walmart_trends['date']
# Out:
# 0     2010-12-05
# 1     2010-12-12
# 2     2010-12-19
# 3     2010-12-26
# 4     2011-01-02
#          ...
# 313   2016-12-04
# 314   2016-12-11
# 315   2016-12-18
# 316   2016-12-25
# 317   2017-01-01
# Name: date, Length: 318, dtype: datetime64[ns]

# %%
walmart_trends_expanded = []
for i, d in zip(walmart_trends['Walmart: (United States)'].items(), walmart_trends['date'].items()):
    for days in range(0, 7):
        walmart_trends_expanded.append({'Walmart: (United States)': i[1], 'date': d[1] + timedelta(days=days)})
walmart_trends_df = pd.DataFrame(walmart_trends_expanded)

# %% [markdown]
# #### Pre-process calendar

# %%
cal["date"] = pd.to_datetime(cal["date"], infer_datetime_format=True)

# %%
cal['date'].min(), cal['date'].max(), walmart_trends['date'].min(), walmart_trends['date'].max()
# Out:
# (Timestamp('2011-01-29 00:00:00'),
#  Timestamp('2016-06-19 00:00:00'),
#  Timestamp('2010-12-05 00:00:00'),
#  Timestamp('2017-01-01 00:00:00'))

# %%
cal['walmart_google_trends'] = pd.merge(cal, walmart_trends_df, how='left', left_on='date', right_on='date')['Walmart: (United States)']

# %%
cal.head(40)
# Out:
#          date  wm_yr_wk    weekday  wday  month  year     d   event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011   d_1            NaN
# 1  2011-01-30     11101     Sunday     2      1  2011   d_2            NaN
# 2  2011-01-31     11101     Monday     3      1  2011   d_3            NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011   d_4            NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011   d_5            NaN
# 5  2011-02-03     11101   Thursday     6      2  2011   d_6            NaN
# 6  2011-02-04     11101     Friday     7      2  2011   d_7            NaN
# 7  2011-02-05     11102   Saturday     1      2  2011   d_8            NaN
# 8  2011-02-06     11102     Sunday     2      2  2011   d_9      SuperBowl
# 9  2011-02-07     11102     Monday     3      2  2011  d_10            NaN
# 10 2011-02-08     11102    Tuesday     4      2  2011  d_11            NaN
# 11 2011-02-09     11102  Wednesday     5      2  2011  d_12            NaN
# 12 2011-02-10     11102   Thursday     6      2  2011  d_13            NaN
# 13 2011-02-11     11102     Friday     7      2  2011  d_14            NaN
# 14 2011-02-12     11103   Saturday     1      2  2011  d_15            NaN
# 15 2011-02-13     11103     Sunday     2      2  2011  d_16            NaN
# 16 2011-02-14     11103     Monday     3      2  2011  d_17  ValentinesDay
# 17 2011-02-15     11103    Tuesday     4      2  2011  d_18            NaN
# 18 2011-02-16     11103  Wednesday     5      2  2011  d_19            NaN
# 19 2011-02-17     11103   Thursday     6      2  2011  d_20            NaN
# 20 2011-02-18     11103     Friday     7      2  2011  d_21            NaN
# 21 2011-02-19     11104   Saturday     1      2  2011  d_22            NaN
# 22 2011-02-20     11104     Sunday     2      2  2011  d_23            NaN
# 23 2011-02-21     11104     Monday     3      2  2011  d_24  PresidentsDay
# 24 2011-02-22     11104    Tuesday     4      2  2011  d_25            NaN
# 25 2011-02-23     11104  Wednesday     5      2  2011  d_26            NaN
# 26 2011-02-24     11104   Thursday     6      2  2011  d_27            NaN
# 27 2011-02-25     11104     Friday     7      2  2011  d_28            NaN
# 28 2011-02-26     11105   Saturday     1      2  2011  d_29            NaN
# 29 2011-02-27     11105     Sunday     2      2  2011  d_30            NaN
# 30 2011-02-28     11105     Monday     3      2  2011  d_31            NaN
# 31 2011-03-01     11105    Tuesday     4      3  2011  d_32            NaN
# 32 2011-03-02     11105  Wednesday     5      3  2011  d_33            NaN
# 33 2011-03-03     11105   Thursday     6      3  2011  d_34            NaN
# 34 2011-03-04     11105     Friday     7      3  2011  d_35            NaN
# 35 2011-03-05     11106   Saturday     1      3  2011  d_36            NaN
# 36 2011-03-06     11106     Sunday     2      3  2011  d_37            NaN
# 37 2011-03-07     11106     Monday     3      3  2011  d_38            NaN
# 38 2011-03-08     11106    Tuesday     4      3  2011  d_39            NaN
# 39 2011-03-09     11106  Wednesday     5      3  2011  d_40      LentStart
#
#    event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  \
# 0           NaN          NaN          NaN      0.0      0.0      0.0
# 1           NaN          NaN          NaN      0.0      0.0      0.0
# 2           NaN          NaN          NaN      0.0      0.0      0.0
# 3           NaN          NaN          NaN      1.0      1.0      0.0
# 4           NaN          NaN          NaN      1.0      0.0      1.0
# 5           NaN          NaN          NaN      1.0      1.0      1.0
# 6           NaN          NaN          NaN      1.0      0.0      0.0
# 7           NaN          NaN          NaN      1.0      1.0      1.0
# 8      Sporting          NaN          NaN      1.0      1.0      1.0
# 9           NaN          NaN          NaN      1.0      1.0      0.0
# 10          NaN          NaN          NaN      1.0      0.0      1.0
# 11          NaN          NaN          NaN      1.0      1.0      1.0
# 12          NaN          NaN          NaN      1.0      0.0      0.0
# 13          NaN          NaN          NaN      0.0      1.0      1.0
# 14          NaN          NaN          NaN      0.0      1.0      1.0
# 15          NaN          NaN          NaN      0.0      1.0      0.0
# 16     Cultural          NaN          NaN      0.0      0.0      1.0
# 17          NaN          NaN          NaN      0.0      1.0      1.0
# 18          NaN          NaN          NaN      0.0      0.0      0.0
# 19          NaN          NaN          NaN      0.0      0.0      0.0
# 20          NaN          NaN          NaN      0.0      0.0      0.0
# 21          NaN          NaN          NaN      0.0      0.0      0.0
# 22          NaN          NaN          NaN      0.0      0.0      0.0
# 23     National          NaN          NaN      0.0      0.0      0.0
# 24          NaN          NaN          NaN      0.0      0.0      0.0
# 25          NaN          NaN          NaN      0.0      0.0      0.0
# 26          NaN          NaN          NaN      0.0      0.0      0.0
# 27          NaN          NaN          NaN      0.0      0.0      0.0
# 28          NaN          NaN          NaN      0.0      0.0      0.0
# 29          NaN          NaN          NaN      0.0      0.0      0.0
# 30          NaN          NaN          NaN      0.0      0.0      0.0
# 31          NaN          NaN          NaN      1.0      1.0      0.0
# 32          NaN          NaN          NaN      1.0      0.0      1.0
# 33          NaN          NaN          NaN      1.0      1.0      1.0
# 34          NaN          NaN          NaN      1.0      0.0      0.0
# 35          NaN          NaN          NaN      1.0      1.0      1.0
# 36          NaN          NaN          NaN      1.0      1.0      1.0
# 37          NaN          NaN          NaN      1.0      1.0      0.0
# 38          NaN          NaN          NaN      1.0      0.0      1.0
# 39    Religious          NaN          NaN      1.0      1.0      1.0
#
#     walmart_google_trends
# 0                      19
# 1                      20
# 2                      20
# 3                      20
# 4                      20
# 5                      20
# 6                      20
# 7                      20
# 8                      20
# 9                      20
# 10                     20
# 11                     20
# 12                     20
# 13                     20
# 14                     20
# 15                     20
# 16                     20
# 17                     20
# 18                     20
# 19                     20
# 20                     20
# 21                     20
# 22                     20
# 23                     20
# 24                     20
# 25                     20
# 26                     20
# 27                     20
# 28                     20
# 29                     20
# 30                     20
# 31                     20
# 32                     20
# 33                     20
# 34                     20
# 35                     20
# 36                     19
# 37                     19
# 38                     19
# 39                     19

# %%
def numericalize(df, type_map):
    for col, col_dtype in type_map.items():
        if col_dtype == "category":
            df[col] = df[col].cat.codes.astype('int16')
            df[col] -= df[col].min()

# %%
numericalize(prices, PRICE_DTYPES)
numericalize(cal, CAL_DTYPES)

# %%
prices.head()
# Out:
#    store_id  item_id  wm_yr_wk  sell_price
# 0         0        0     11325        9.58
# 1         0        0     11326        9.58
# 2         0        0     11327        8.26
# 3         0        0     11328        8.26
# 4         0        0     11329        8.26

# %%
pred_days = 28
max_lags = pred_days * 2 + 1
print('max_lags', max_lags)
num_cols = [c for c in pd.read_csv(path/"sales_train_validation.csv", nrows=2).columns if c.find('d_') == 0]
tr_last = len(num_cols)
catcols = ['id', 'item_id', 'dept_id','store_id', 'cat_id', 'state_id']
# For more training data use a lower value
FIRST_DAY=1
# Out:
# max_lags 57

# %%
def read_dt(is_train = True, nrows = None, first_day = 1200):
    start_day = max(1 if is_train else tr_last - max_lags, first_day)
    print('start_day', start_day)
    dtype = {num: 'float32' for num in num_cols}
    dtype.update({cat: 'category' for cat in catcols if cat != 'id'})
    numcols = [f"d_{day}" for day in range(start_day,tr_last+1)]
    dt = pd.read_csv(path/"sales_train_validation.csv", nrows=nrows, usecols = catcols + numcols, dtype=dtype)
    for col in catcols:
        if col != 'id':
            dt[col] = dt[col].cat.codes.astype('int16')
            dt[col] -= dt[col].min()
    if not is_train:
        for day in range(tr_last + 1, tr_last + 1 + pred_days):
            dt[f'd_{day}'] = np.nan
            
    dt = dt.melt(id_vars=catcols, value_vars=[col for col in dt.columns if col.startswith("d_")], var_name='d', value_name='sales')
    dt = dt.merge(cal, on='d', copy=False)
    dt = dt.merge(prices, on=['store_id', 'item_id', 'wm_yr_wk'], copy=False)
    return dt

# %%
# %%time

dt = read_dt(first_day=FIRST_DAY)
# Out:
# start_day 1
# CPU times: user 15.2 s, sys: 2.66 s, total: 17.9 s
# Wall time: 17.9 s

# %%
dt.shape
# Out:
# (46027957, 23)

# %%
dt
# Out:
#                                      id  item_id  dept_id  store_id  cat_id  \
# 0         HOBBIES_1_008_CA_1_validation        7        0         0       0
# 1         HOBBIES_1_008_CA_1_validation        7        0         0       0
# 2         HOBBIES_1_008_CA_1_validation        7        0         0       0
# 3         HOBBIES_1_008_CA_1_validation        7        0         0       0
# 4         HOBBIES_1_008_CA_1_validation        7        0         0       0
# ...                                 ...      ...      ...       ...     ...
# 46027952    FOODS_3_825_WI_3_validation     3046        6         9       2
# 46027953    FOODS_3_826_WI_3_validation     3047        6         9       2
# 46027954    FOODS_3_826_WI_3_validation     3047        6         9       2
# 46027955    FOODS_3_827_WI_3_validation     3048        6         9       2
# 46027956    FOODS_3_827_WI_3_validation     3048        6         9       2
#
#           state_id       d  sales       date  wm_yr_wk  weekday  wday  month  \
# 0                0     d_1   12.0 2011-01-29     11101        2     1      1
# 1                0     d_2   15.0 2011-01-30     11101        3     2      1
# 2                0     d_3    0.0 2011-01-31     11101        1     3      1
# 3                0     d_4    0.0 2011-02-01     11101        5     4      2
# 4                0     d_5    0.0 2011-02-02     11101        6     5      2
# ...            ...     ...    ...        ...       ...      ...   ...    ...
# 46027952         2  d_1913    0.0 2016-04-24     11613        3     2      4
# 46027953         2  d_1912    1.0 2016-04-23     11613        2     1      4
# 46027954         2  d_1913    3.0 2016-04-24     11613        3     2      4
# 46027955         2  d_1912    0.0 2016-04-23     11613        2     1      4
# 46027956         2  d_1913    0.0 2016-04-24     11613        3     2      4
#
#           year  event_name_1  event_type_1  event_name_2  event_type_2  \
# 0         2011             0             0             0             0
# 1         2011             0             0             0             0
# 2         2011             0             0             0             0
# 3         2011             0             0             0             0
# 4         2011             0             0             0             0
# ...        ...           ...           ...           ...           ...
# 46027952  2016             0             0             0             0
# 46027953  2016             0             0             0             0
# 46027954  2016             0             0             0             0
# 46027955  2016             0             0             0             0
# 46027956  2016             0             0             0             0
#
#           snap_CA  snap_TX  snap_WI  walmart_google_trends  sell_price
# 0             0.0      0.0      0.0                     19        0.46
# 1             0.0      0.0      0.0                     20        0.46
# 2             0.0      0.0      0.0                     20        0.46
# 3             1.0      1.0      0.0                     20        0.46
# 4             1.0      0.0      1.0                     20        0.46
# ...           ...      ...      ...                    ...         ...
# 46027952      0.0      0.0      0.0                     25        3.98
# 46027953      0.0      0.0      0.0                     25        1.28
# 46027954      0.0      0.0      0.0                     25        1.28
# 46027955      0.0      0.0      0.0                     25        1.00
# 46027956      0.0      0.0      0.0                     25        1.00
#
# [46027957 rows x 23 columns]

# %%
dt.date.min(), dt.date.max()
# Out:
# (Timestamp('2011-01-29 00:00:00'), Timestamp('2016-04-24 00:00:00'))

# %% [markdown]
# ## Create features

# %%
def create_features(dt):
    lags = [7, 28]
    lag_cols = [f'sales_lag_{lag}' for lag in lags]
    for lag, lag_col in zip(lags, lag_cols):
        dt[lag_col] = dt[['id', 'sales']].groupby('id')['sales'].shift(lag)
        
    for win in lags:
        for lag, lag_col in zip(lags, lag_cols):
            grouped = dt[['id', lag_col]].groupby('id')[lag_col]
            dt[f'rmean_{lag}_{win}'] = grouped.transform(lambda x : x.rolling(win).mean())

# %%
# %%time
create_features(dt)
# Out:
# CPU times: user 1min 36s, sys: 6.62 s, total: 1min 43s
# Wall time: 1min 43s

# %%
# attr = ['Dayofyear',
#             'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
attr = []
date_features = {
    "wday": "weekday",
    "week": "weekofyear",
    "month": "month",
    "quarter": "quarter",
    "year": "year",
    "mday": "day"
}

for f in attr:
    date_features[f.lower()] = f.lower()
    
date_features
# Out:
# {'wday': 'weekday',
#  'week': 'weekofyear',
#  'month': 'month',
#  'quarter': 'quarter',
#  'year': 'year',
#  'mday': 'day'}

# %%
def prepare_date_cols(dt):
    for date_feature_name, date_feature_func in date_features.items():
        if date_feature_name in dt.columns:
            dt[date_feature_name] = dt[date_feature_name].astype('int16')
        else:
            dt[date_feature_name] = getattr(dt['date'].dt, date_feature_func).astype('int16')

# %%
# %%time
prepare_date_cols(dt)
# Out:
# CPU times: user 7.87 s, sys: 199 ms, total: 8.07 s
# Wall time: 8.07 s

# %%
dt.dropna(inplace = True)

# %%
dt
# Out:
#                                      id  item_id  dept_id  store_id  cat_id  \
# 617364    HOBBIES_1_008_CA_1_validation        7        0         0       0
# 617371    HOBBIES_1_009_CA_1_validation        8        0         0       0
# 617378    HOBBIES_1_010_CA_1_validation        9        0         0       0
# 617385    HOBBIES_1_012_CA_1_validation       11        0         0       0
# 617392    HOBBIES_1_015_CA_1_validation       14        0         0       0
# ...                                 ...      ...      ...       ...     ...
# 46027952    FOODS_3_825_WI_3_validation     3046        6         9       2
# 46027953    FOODS_3_826_WI_3_validation     3047        6         9       2
# 46027954    FOODS_3_826_WI_3_validation     3047        6         9       2
# 46027955    FOODS_3_827_WI_3_validation     3048        6         9       2
# 46027956    FOODS_3_827_WI_3_validation     3048        6         9       2
#
#           state_id       d  sales       date  wm_yr_wk  weekday  wday  month  \
# 617364           0    d_56    0.0 2011-03-25     11108        0     7      3
# 617371           0    d_56    0.0 2011-03-25     11108        0     7      3
# 617378           0    d_56    0.0 2011-03-25     11108        0     7      3
# 617385           0    d_56    1.0 2011-03-25     11108        0     7      3
# 617392           0    d_56    1.0 2011-03-25     11108        0     7      3
# ...            ...     ...    ...        ...       ...      ...   ...    ...
# 46027952         2  d_1913    0.0 2016-04-24     11613        3     2      4
# 46027953         2  d_1912    1.0 2016-04-23     11613        2     1      4
# 46027954         2  d_1913    3.0 2016-04-24     11613        3     2      4
# 46027955         2  d_1912    0.0 2016-04-23     11613        2     1      4
# 46027956         2  d_1913    0.0 2016-04-24     11613        3     2      4
#
#           year  event_name_1  event_type_1  event_name_2  event_type_2  \
# 617364    2011             0             0             0             0
# 617371    2011             0             0             0             0
# 617378    2011             0             0             0             0
# 617385    2011             0             0             0             0
# 617392    2011             0             0             0             0
# ...        ...           ...           ...           ...           ...
# 46027952  2016             0             0             0             0
# 46027953  2016             0             0             0             0
# 46027954  2016             0             0             0             0
# 46027955  2016             0             0             0             0
# 46027956  2016             0             0             0             0
#
#           snap_CA  snap_TX  snap_WI  walmart_google_trends  sell_price  \
# 617364        0.0      0.0      0.0                     19        0.42
# 617371        0.0      0.0      0.0                     19        1.77
# 617378        0.0      0.0      0.0                     19        3.17
# 617385        0.0      0.0      0.0                     19        6.27
# 617392        0.0      0.0      0.0                     19        0.72
# ...           ...      ...      ...                    ...         ...
# 46027952      0.0      0.0      0.0                     25        3.98
# 46027953      0.0      0.0      0.0                     25        1.28
# 46027954      0.0      0.0      0.0                     25        1.28
# 46027955      0.0      0.0      0.0                     25        1.00
# 46027956      0.0      0.0      0.0                     25        1.00
#
#           sales_lag_7  sales_lag_28  rmean_7_7  rmean_28_7  rmean_7_28  \
# 617364            0.0           0.0   2.000000    4.000000    1.642857
# 617371            0.0           0.0   2.000000    2.000000    2.142857
# 617378            0.0           0.0   0.000000    0.142857    0.035714
# 617385            1.0           1.0   0.428571    0.857143    0.535714
# 617392            2.0           1.0   5.428571    8.000000    6.142857
# ...               ...           ...        ...         ...         ...
# 46027952          0.0           1.0   1.000000    0.714286    0.928571
# 46027953          0.0           2.0   0.857143    1.142857    1.035714
# 46027954          1.0           4.0   0.714286    1.571429    1.035714
# 46027955          0.0           0.0   0.000000    2.285714    1.821429
# 46027956          0.0           5.0   0.000000    2.428571    1.678571
#
#           rmean_28_28  week  quarter  mday
# 617364       4.535714    12        1    25
# 617371       2.178571    12        1    25
# 617378       0.214286    12        1    25
# 617385       0.678571    12        1    25
# 617392       4.321429    12        1    25
# ...               ...   ...      ...   ...
# 46027952     1.250000    16        2    24
# 46027953     1.107143    16        2    23
# 46027954     1.250000    16        2    24
# 46027955     1.785714    16        2    23
# 46027956     1.964286    16        2    24
#
# [44351007 rows x 32 columns]

# %%
dt[dt.date == datetime(2014, 1, 1)].head(30)
# Out:
#                                      id  item_id  dept_id  store_id  cat_id  \
# 21099166  HOBBIES_1_001_CA_1_validation        0        0         0       0
# 21099173  HOBBIES_1_002_CA_1_validation        1        0         0       0
# 21099180  HOBBIES_1_004_CA_1_validation        3        0         0       0
# 21099187  HOBBIES_1_005_CA_1_validation        4        0         0       0
# 21099194  HOBBIES_1_006_CA_1_validation        5        0         0       0
# 21099201  HOBBIES_1_007_CA_1_validation        6        0         0       0
# 21099208  HOBBIES_1_008_CA_1_validation        7        0         0       0
# 21099215  HOBBIES_1_009_CA_1_validation        8        0         0       0
# 21099222  HOBBIES_1_010_CA_1_validation        9        0         0       0
# 21099229  HOBBIES_1_011_CA_1_validation       10        0         0       0
# 21099236  HOBBIES_1_012_CA_1_validation       11        0         0       0
# 21099243  HOBBIES_1_013_CA_1_validation       12        0         0       0
# 21099250  HOBBIES_1_014_CA_1_validation       13        0         0       0
# 21099257  HOBBIES_1_015_CA_1_validation       14        0         0       0
# 21099264  HOBBIES_1_016_CA_1_validation       15        0         0       0
# 21099271  HOBBIES_1_017_CA_1_validation       16        0         0       0
# 21099278  HOBBIES_1_018_CA_1_validation       17        0         0       0
# 21099285  HOBBIES_1_019_CA_1_validation       18        0         0       0
# 21099292  HOBBIES_1_020_CA_1_validation       19        0         0       0
# 21099299  HOBBIES_1_021_CA_1_validation       20        0         0       0
# 21099306  HOBBIES_1_022_CA_1_validation       21        0         0       0
# 21099313  HOBBIES_1_023_CA_1_validation       22        0         0       0
# 21099320  HOBBIES_1_024_CA_1_validation       23        0         0       0
# 21099327  HOBBIES_1_025_CA_1_validation       24        0         0       0
# 21099334  HOBBIES_1_028_CA_1_validation       27        0         0       0
# 21099341  HOBBIES_1_029_CA_1_validation       28        0         0       0
# 21099348  HOBBIES_1_030_CA_1_validation       29        0         0       0
# 21099355  HOBBIES_1_031_CA_1_validation       30        0         0       0
# 21099362  HOBBIES_1_032_CA_1_validation       31        0         0       0
# 21099369  HOBBIES_1_033_CA_1_validation       32        0         0       0
#
#           state_id       d  sales       date  wm_yr_wk  weekday  wday  month  \
# 21099166         0  d_1069    1.0 2014-01-01     11349        6     5      1
# 21099173         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 21099180         0  d_1069    2.0 2014-01-01     11349        6     5      1
# 21099187         0  d_1069    1.0 2014-01-01     11349        6     5      1
# 21099194         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 21099201         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 21099208         0  d_1069    3.0 2014-01-01     11349        6     5      1
# 21099215         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 21099222         0  d_1069    3.0 2014-01-01     11349        6     5      1
# 21099229         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 21099236         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 21099243         0  d_1069    1.0 2014-01-01     11349        6     5      1
# 21099250         0  d_1069    1.0 2014-01-01     11349        6     5      1
# 21099257         0  d_1069   14.0 2014-01-01     11349        6     5      1
# 21099264         0  d_1069    5.0 2014-01-01     11349        6     5      1
# 21099271         0  d_1069    2.0 2014-01-01     11349        6     5      1
# 21099278         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 21099285         0  d_1069    2.0 2014-01-01     11349        6     5      1
# 21099292         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 21099299         0  d_1069    2.0 2014-01-01     11349        6     5      1
# 21099306         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 21099313         0  d_1069    1.0 2014-01-01     11349        6     5      1
# 21099320         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 21099327         0  d_1069    1.0 2014-01-01     11349        6     5      1
# 21099334         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 21099341         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 21099348         0  d_1069    2.0 2014-01-01     11349        6     5      1
# 21099355         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 21099362         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 21099369         0  d_1069    2.0 2014-01-01     11349        6     5      1
#
#           year  event_name_1  event_type_1  event_name_2  event_type_2  \
# 21099166  2014            19             2             0             0
# 21099173  2014            19             2             0             0
# 21099180  2014            19             2             0             0
# 21099187  2014            19             2             0             0
# 21099194  2014            19             2             0             0
# 21099201  2014            19             2             0             0
# 21099208  2014            19             2             0             0
# 21099215  2014            19             2             0             0
# 21099222  2014            19             2             0             0
# 21099229  2014            19             2             0             0
# 21099236  2014            19             2             0             0
# 21099243  2014            19             2             0             0
# 21099250  2014            19             2             0             0
# 21099257  2014            19             2             0             0
# 21099264  2014            19             2             0             0
# 21099271  2014            19             2             0             0
# 21099278  2014            19             2             0             0
# 21099285  2014            19             2             0             0
# 21099292  2014            19             2             0             0
# 21099299  2014            19             2             0             0
# 21099306  2014            19             2             0             0
# 21099313  2014            19             2             0             0
# 21099320  2014            19             2             0             0
# 21099327  2014            19             2             0             0
# 21099334  2014            19             2             0             0
# 21099341  2014            19             2             0             0
# 21099348  2014            19             2             0             0
# 21099355  2014            19             2             0             0
# 21099362  2014            19             2             0             0
# 21099369  2014            19             2             0             0
#
#           snap_CA  snap_TX  snap_WI  walmart_google_trends  sell_price  \
# 21099166      1.0      1.0      0.0                     32        8.26
# 21099173      1.0      1.0      0.0                     32        3.97
# 21099180      1.0      1.0      0.0                     32        4.64
# 21099187      1.0      1.0      0.0                     32        3.08
# 21099194      1.0      1.0      0.0                     32        1.00
# 21099201      1.0      1.0      0.0                     32        7.88
# 21099208      1.0      1.0      0.0                     32        0.46
# 21099215      1.0      1.0      0.0                     32        1.77
# 21099222      1.0      1.0      0.0                     32        2.97
# 21099229      1.0      1.0      0.0                     32        3.48
# 21099236      1.0      1.0      0.0                     32        6.52
# 21099243      1.0      1.0      0.0                     32        1.97
# 21099250      1.0      1.0      0.0                     32        0.98
# 21099257      1.0      1.0      0.0                     32        0.70
# 21099264      1.0      1.0      0.0                     32        0.70
# 21099271      1.0      1.0      0.0                     32        1.98
# 21099278      1.0      1.0      0.0                     32       11.88
# 21099285      1.0      1.0      0.0                     32        0.46
# 21099292      1.0      1.0      0.0                     32       12.68
# 21099299      1.0      1.0      0.0                     32       11.88
# 21099306      1.0      1.0      0.0                     32        7.18
# 21099313      1.0      1.0      0.0                     32        3.44
# 21099320      1.0      1.0      0.0                     32        8.98
# 21099327      1.0      1.0      0.0                     32        3.98
# 21099334      1.0      1.0      0.0                     32        7.98
# 21099341      1.0      1.0      0.0                     32        8.98
# 21099348      1.0      1.0      0.0                     32        0.70
# 21099355      1.0      1.0      0.0                     32       10.98
# 21099362      1.0      1.0      0.0                     32        0.58
# 21099369      1.0      1.0      0.0                     32       15.97
#
#           sales_lag_7  sales_lag_28  rmean_7_7  rmean_28_7  rmean_7_28  \
# 21099166          0.0           1.0   0.714286    1.000000    0.857143
# 21099173          0.0           0.0   0.285714    0.000000    0.357143
# 21099180          0.0           1.0   1.857143    3.142857    2.464286
# 21099187          0.0           1.0   1.428571    1.000000    1.071429
# 21099194          0.0           1.0   0.285714    0.714286    0.607143
# 21099201          0.0           0.0   0.714286    0.142857    0.392857
# 21099208          0.0          11.0   5.428571    5.714286    6.214286
# 21099215          0.0           1.0   1.571429    1.285714    1.428571
# 21099222          0.0           2.0   0.571429    1.142857    0.714286
# 21099229          0.0           0.0   0.000000    0.000000    0.107143
# 21099236          0.0           0.0   0.714286    0.428571    0.428571
# 21099243          0.0           0.0   0.428571    0.428571    0.321429
# 21099250          0.0           3.0   1.142857    1.714286    1.357143
# 21099257          0.0           0.0  18.428572    9.285714   12.285714
# 21099264          0.0           0.0   4.571429    9.428572    5.250000
# 21099271          0.0           4.0   1.000000    1.285714    0.892857
# 21099278          0.0           0.0   0.000000    0.000000    0.000000
# 21099285          0.0           7.0  11.000000   12.142858    9.964286
# 21099292          0.0           0.0   0.142857    0.285714    0.214286
# 21099299          0.0           1.0   1.000000    0.857143    0.964286
# 21099306          0.0           2.0   0.142857    0.285714    0.214286
# 21099313          0.0           1.0   0.714286    0.714286    0.785714
# 21099320          0.0           0.0   0.000000    0.428571    0.428571
# 21099327          0.0           1.0   1.142857    0.571429    0.642857
# 21099334          0.0           2.0   0.857143    1.142857    0.964286
# 21099341          0.0           0.0   1.428571    2.285714    1.964286
# 21099348          0.0           5.0   4.857143    4.142857    4.750000
# 21099355          0.0           1.0   0.142857    0.285714    0.250000
# 21099362          0.0           0.0   4.142857    5.428571    5.142857
# 21099369          0.0           0.0   0.428571    0.142857    0.250000
#
#           rmean_28_28  week  quarter  mday
# 21099166     0.714286     1        1     1
# 21099173     0.071429     1        1     1
# 21099180     2.107143     1        1     1
# 21099187     0.750000     1        1     1
# 21099194     1.035714     1        1     1
# 21099201     0.392857     1        1     1
# 21099208     8.250000     1        1     1
# 21099215     1.464286     1        1     1
# 21099222     0.785714     1        1     1
# 21099229     0.107143     1        1     1
# 21099236     0.607143     1        1     1
# 21099243     0.500000     1        1     1
# 21099250     1.428571     1        1     1
# 21099257     7.500000     1        1     1
# 21099264     4.857143     1        1     1
# 21099271     1.607143     1        1     1
# 21099278     0.000000     1        1     1
# 21099285    11.464286     1        1     1
# 21099292     0.142857     1        1     1
# 21099299     0.821429     1        1     1
# 21099306     0.500000     1        1     1
# 21099313     0.857143     1        1     1
# 21099320     0.285714     1        1     1
# 21099327     0.464286     1        1     1
# 21099334     0.892857     1        1     1
# 21099341     1.642857     1        1     1
# 21099348     4.535714     1        1     1
# 21099355     0.464286     1        1     1
# 21099362     4.178571     1        1     1
# 21099369     0.142857     1        1     1

# %% [markdown]
# ## Training Preparation

# %%
dt.columns
# Out:
# Index(['id', 'item_id', 'dept_id', 'store_id', 'cat_id', 'state_id', 'd',
#        'sales', 'date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year',
#        'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2',
#        'snap_CA', 'snap_TX', 'snap_WI', 'walmart_google_trends', 'sell_price',
#        'sales_lag_7', 'sales_lag_28', 'rmean_7_7', 'rmean_28_7', 'rmean_7_28',
#        'rmean_28_28', 'week', 'quarter', 'mday'],
#       dtype='object')

# %%
cat_feats = ['item_id', 'dept_id', 'store_id', 'cat_id', 'state_id', 'event_name_1', 
             'event_type_1', 'event_name_2', 'event_type_2']
ignore_cols = ['id', 'date', 'sales', 'd', 'wm_yr_wk', 'weekday']
train_cols = [c for c in dt.columns if c not in ignore_cols]
X = dt[train_cols]
Y = dt['sales']

# %%
valid_size = int(X.shape[0] * 0.1)
np.random.seed(777)

valid_idx = np.random.choice(X.index.values, valid_size, replace=False)
train_idx = np.setdiff1d(X.index.values, valid_idx)
assert valid_idx.size + train_idx.size == X.shape[0]

# %%
train_data = lgb.Dataset(X.loc[train_idx], Y.loc[train_idx], categorical_feature=cat_feats, free_raw_data=False)
valid_data = lgb.Dataset(X.loc[valid_idx], Y.loc[valid_idx], categorical_feature=cat_feats, free_raw_data=False)

# %%
del dt, X, Y, valid_idx, train_idx
gc.collect()
# Out:
# 120

# %%
del walmart_trends
gc.collect()
# Out:
# 20

# %% [markdown]
# ## Training

# %%
lgb_params = {
        "objective" : "poisson",
        "learning_rate" : 0.075,
#         "sub_feature" : 0.8,
        "sub_row" : 0.75,
        "bagging_freq" : 1,
        "lambda_l2" : 0.1,
#         "nthread" : 4
        "metric": ["rmse"],
        'verbosity': 1,
        'num_leaves': 128,
        "min_data_in_leaf": 100,
}

# %%
# %%time
m_lgb = lgb.train(lgb_params, train_data, valid_sets=[valid_data], verbose_eval=20, categorical_feature=cat_feats, num_boost_round=1200)
# Out:
# [20]	valid_0's rmse: 3.19667
# [40]	valid_0's rmse: 2.64326
# [60]	valid_0's rmse: 2.48965
# [80]	valid_0's rmse: 2.44402
# [100]	valid_0's rmse: 2.43129
# [120]	valid_0's rmse: 2.42241
# [140]	valid_0's rmse: 2.41537
# [160]	valid_0's rmse: 2.40767
# [180]	valid_0's rmse: 2.40033
# [200]	valid_0's rmse: 2.39333
# [220]	valid_0's rmse: 2.38787
# [240]	valid_0's rmse: 2.38269
# [260]	valid_0's rmse: 2.37807
# [280]	valid_0's rmse: 2.37291
# [300]	valid_0's rmse: 2.36928
# [320]	valid_0's rmse: 2.36509
# [340]	valid_0's rmse: 2.36182
# [360]	valid_0's rmse: 2.35768
# [380]	valid_0's rmse: 2.35381
# [400]	valid_0's rmse: 2.35122
# [420]	valid_0's rmse: 2.34799
# [440]	valid_0's rmse: 2.34483
# [460]	valid_0's rmse: 2.3428
# [480]	valid_0's rmse: 2.34039
# [500]	valid_0's rmse: 2.33791
# [520]	valid_0's rmse: 2.33636
# [540]	valid_0's rmse: 2.33455
# [560]	valid_0's rmse: 2.33232
# [580]	valid_0's rmse: 2.33013
# [600]	valid_0's rmse: 2.32865
# [620]	valid_0's rmse: 2.32654
# [640]	valid_0's rmse: 2.32444
# [660]	valid_0's rmse: 2.32291
# [680]	valid_0's rmse: 2.32121
# [700]	valid_0's rmse: 2.31944
# [720]	valid_0's rmse: 2.31794
# [740]	valid_0's rmse: 2.31686
# [760]	valid_0's rmse: 2.31494
# [780]	valid_0's rmse: 2.31324
# [800]	valid_0's rmse: 2.31211
# [820]	valid_0's rmse: 2.311
# [840]	valid_0's rmse: 2.30961
# [860]	valid_0's rmse: 2.30801
# [880]	valid_0's rmse: 2.30712
# [900]	valid_0's rmse: 2.30621
# [920]	valid_0's rmse: 2.305
# [940]	valid_0's rmse: 2.30366
# [960]	valid_0's rmse: 2.3025
# [980]	valid_0's rmse: 2.30131
# [1000]	valid_0's rmse: 2.30051
# [1020]	valid_0's rmse: 2.29923
# [1040]	valid_0's rmse: 2.29807
# [1060]	valid_0's rmse: 2.29705
# [1080]	valid_0's rmse: 2.29584
# [1100]	valid_0's rmse: 2.29437
# [1120]	valid_0's rmse: 2.29334
# [1140]	valid_0's rmse: 2.29272
# [1160]	valid_0's rmse: 2.2919
# [1180]	valid_0's rmse: 2.29098
# [1200]	valid_0's rmse: 2.29019
# CPU times: user 4h 12min 48s, sys: 54.4 s, total: 4h 13min 43s
# Wall time: 42min 36s

# %%
str(path/'m5_model.lgb')
# Out:
# '/kaggle/m5_forecasting/m5_model.lgb'

# %%
m_lgb.save_model(str(path/'m5_model.lgb'))

# %%
m_lgb = lgb.Booster(model_file=str(path/'m5_model.lgb'))

# %% [markdown]
# ## Prediction

# %%
from tqdm.notebook import tqdm

# %%
alphas = [1.028, 1.023, 1.018]
weights = [1 / len(alphas)] * len(alphas)
assert sum(weights) == 1.0
fday = datetime(2016, 4, 25) 
assert datetime(2011, 1, 29) + timedelta(days=1914 - 1) == fday

# %%
cols = [f'F{i}' for i in range(1, pred_days + 1)]
sub = pd.DataFrame()
te = read_dt(False)

for icount, (alpha, weight) in tqdm(enumerate(zip(alphas, weights)), total=len(alphas)):
    for tdelta in tqdm(range(0, pred_days), total=pred_days):
        day = fday + timedelta(days=tdelta)
        print(tdelta, day)
        tst = te[(te.date >= day - timedelta(days=max_lags)) & (te.date <= day)].copy()
        create_features(tst)
        prepare_date_cols(tst)
        tst = tst.loc[tst.date == day, train_cols]
        te.loc[te.date == day, 'sales'] = alpha * m_lgb.predict(tst) # magic multiplier by kyakovlev
    
    te_sub = te.loc[te.date >= fday, ['id', 'sales']].copy()
    te_sub['F'] = [f"F{rank}" for rank in te_sub.groupby("id")["id"].cumcount()+1]
    te_sub = te_sub.set_index(["id", "F" ]).unstack()['sales'][cols]
    te_sub.fillna(0., inplace=True)
    te_sub.sort_values(["id"], inplace=True)
    te_sub.reset_index(drop=False, inplace = True)
    te_sub.to_csv(f"submission_{icount}.csv",index=False)
    
    if icount == 0:
        sub = te_sub
        sub[cols] *= weight
    else:
        sub[cols] += te_sub[cols] * weight

sub2 = sub.copy()
sub2["id"] = sub2["id"].str.replace("validation$", "evaluation")
sub = pd.concat([sub, sub2], axis=0, sort=False)
sub.to_csv("submission.csv",index=False)
# Out:
# start_day 1856
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=28.0), HTML(value='')))
# 0 2016-04-25 00:00:00
# 1 2016-04-26 00:00:00
# 2 2016-04-27 00:00:00
# 3 2016-04-28 00:00:00
# 4 2016-04-29 00:00:00
# 5 2016-04-30 00:00:00
# 6 2016-05-01 00:00:00
# 7 2016-05-02 00:00:00
# 8 2016-05-03 00:00:00
# 9 2016-05-04 00:00:00
# 10 2016-05-05 00:00:00
# 11 2016-05-06 00:00:00
# 12 2016-05-07 00:00:00
# 13 2016-05-08 00:00:00
# 14 2016-05-09 00:00:00
# 15 2016-05-10 00:00:00
# 16 2016-05-11 00:00:00
# 17 2016-05-12 00:00:00
# 18 2016-05-13 00:00:00
# 19 2016-05-14 00:00:00
# 20 2016-05-15 00:00:00
# 21 2016-05-16 00:00:00
# 22 2016-05-17 00:00:00
# 23 2016-05-18 00:00:00
# 24 2016-05-19 00:00:00
# 25 2016-05-20 00:00:00
# 26 2016-05-21 00:00:00
# 27 2016-05-22 00:00:00
# HBox(children=(FloatProgress(value=0.0, max=28.0), HTML(value='')))
# 0 2016-04-25 00:00:00
# 1 2016-04-26 00:00:00
# 2 2016-04-27 00:00:00
# 3 2016-04-28 00:00:00
# 4 2016-04-29 00:00:00
# 5 2016-04-30 00:00:00
# 6 2016-05-01 00:00:00
# 7 2016-05-02 00:00:00
# 8 2016-05-03 00:00:00
# 9 2016-05-04 00:00:00
# 10 2016-05-05 00:00:00
# 11 2016-05-06 00:00:00
# 12 2016-05-07 00:00:00
# 13 2016-05-08 00:00:00
# 14 2016-05-09 00:00:00
# 15 2016-05-10 00:00:00
# 16 2016-05-11 00:00:00
# 17 2016-05-12 00:00:00
# 18 2016-05-13 00:00:00
# 19 2016-05-14 00:00:00
# 20 2016-05-15 00:00:00
# 21 2016-05-16 00:00:00
# 22 2016-05-17 00:00:00
# 23 2016-05-18 00:00:00
# 24 2016-05-19 00:00:00
# 25 2016-05-20 00:00:00
# 26 2016-05-21 00:00:00
# 27 2016-05-22 00:00:00
# HBox(children=(FloatProgress(value=0.0, max=28.0), HTML(value='')))
# 0 2016-04-25 00:00:00
# 1 2016-04-26 00:00:00
# 2 2016-04-27 00:00:00
# 3 2016-04-28 00:00:00
# 4 2016-04-29 00:00:00
# 5 2016-04-30 00:00:00
# 6 2016-05-01 00:00:00
# 7 2016-05-02 00:00:00
# 8 2016-05-03 00:00:00
# 9 2016-05-04 00:00:00
# 10 2016-05-05 00:00:00
# 11 2016-05-06 00:00:00
# 12 2016-05-07 00:00:00
# 13 2016-05-08 00:00:00
# 14 2016-05-09 00:00:00
# 15 2016-05-10 00:00:00
# 16 2016-05-11 00:00:00
# 17 2016-05-12 00:00:00
# 18 2016-05-13 00:00:00
# 19 2016-05-14 00:00:00
# 20 2016-05-15 00:00:00
# 21 2016-05-16 00:00:00
# 22 2016-05-17 00:00:00
# 23 2016-05-18 00:00:00
# 24 2016-05-19 00:00:00
# 25 2016-05-20 00:00:00
# 26 2016-05-21 00:00:00
# 27 2016-05-22 00:00:00

# %%
# !wc -l submission.csv
# Out:
# 60981 submission.csv

# %%
pd.read_csv('submission.csv')
# Out:
#                                     id        F1        F2        F3  \
# 0          FOODS_1_001_CA_1_validation  0.941728  0.882507  0.880217
# 1          FOODS_1_001_CA_2_validation  1.116155  1.121406  1.005362
# 2          FOODS_1_001_CA_3_validation  1.124378  1.098403  1.033801
# 3          FOODS_1_001_CA_4_validation  0.417476  0.384001  0.379374
# 4          FOODS_1_001_TX_1_validation  0.177985  0.176080  0.171513
# ...                                ...       ...       ...       ...
# 60975  HOUSEHOLD_2_516_TX_2_evaluation  0.259264  0.239845  0.260041
# 60976  HOUSEHOLD_2_516_TX_3_evaluation  0.172544  0.158776  0.162784
# 60977  HOUSEHOLD_2_516_WI_1_evaluation  0.095257  0.093487  0.093791
# 60978  HOUSEHOLD_2_516_WI_2_evaluation  0.044743  0.043204  0.042494
# 60979  HOUSEHOLD_2_516_WI_3_evaluation  0.055788  0.053657  0.051972
#
#              F4        F5        F6        F7        F8        F9       F10  \
# 0      0.831535  1.137847  1.199630  1.199561  0.998097  0.970100  0.975499
# 1      1.243528  1.342176  1.536274  1.441502  1.002968  1.016579  0.995612
# 2      0.979253  1.052553  1.114425  1.229024  1.101787  1.100687  1.011511
# 3      0.375521  0.462624  0.456527  0.498086  0.426118  0.442529  0.432075
# 4      0.175862  0.165915  0.180612  0.239928  0.549013  0.492527  0.502944
# ...         ...       ...       ...       ...       ...       ...       ...
# 60975  0.258373  0.317446  0.402302  0.378582  0.244213  0.247966  0.241316
# 60976  0.158033  0.180024  0.216313  0.172027  0.125376  0.117394  0.107958
# 60977  0.094461  0.098556  0.114941  0.102419  0.095982  0.096307  0.092880
# 60978  0.093667  0.109824  0.115904  0.101831  0.090910  0.090641  0.086600
# 60979  0.054897  0.067722  0.065937  0.066705  0.102421  0.101215  0.096787
#
#             F11       F12       F13       F14       F15       F16       F17  \
# 0      1.002671  1.130980  1.314221  1.123562  0.957760  0.887815  0.916123
# 1      1.037407  1.257823  1.593927  1.308953  1.145986  1.113787  1.108406
# 2      1.040616  1.157005  1.384097  1.179016  1.091324  1.078977  1.046443
# 3      0.430104  0.423184  0.443226  0.405695  0.377932  0.383694  0.404324
# 4      0.548088  0.575170  0.584624  0.476078  0.407418  0.585339  0.367276
# ...         ...       ...       ...       ...       ...       ...       ...
# 60975  0.263087  0.315754  0.353075  0.313281  0.249224  0.243222  0.245425
# 60976  0.122272  0.131778  0.168704  0.144569  0.120562  0.122175  0.125228
# 60977  0.095864  0.117852  0.148881  0.117244  0.097578  0.093855  0.096105
# 60978  0.114964  0.131340  0.134598  0.115511  0.109735  0.109685  0.107787
# 60979  0.101105  0.116578  0.133509  0.108188  0.121716  0.119903  0.117941
#
#             F18       F19       F20       F21       F22       F23       F24  \
# 0      0.926501  1.079663  1.332937  1.235079  0.945463  0.849102  0.836711
# 1      1.104808  1.338410  1.855680  1.551243  1.132974  1.083434  1.084167
# 2      1.058235  1.149064  1.577763  1.620408  1.090194  1.030493  0.971517
# 3      0.434475  0.477263  0.516618  0.517843  0.384703  0.372949  0.373473
# 4      0.387255  0.392921  0.401339  0.444036  0.362910  0.329429  0.333908
# ...         ...       ...       ...       ...       ...       ...       ...
# 60975  0.253862  0.289157  0.373888  0.367515  0.251593  0.238225  0.248835
# 60976  0.129032  0.148662  0.179969  0.171849  0.143287  0.136366  0.134294
# 60977  0.098321  0.121193  0.141919  0.134117  0.096795  0.093447  0.094031
# 60978  0.112179  0.138464  0.141316  0.123347  0.114520  0.107285  0.107206
# 60979  0.125765  0.156575  0.169024  0.149334  0.127145  0.121665  0.126928
#
#             F25       F26       F27       F28
# 0      0.851794  1.077530  1.271474  1.228209
# 1      1.100001  1.327303  1.821015  1.589146
# 2      0.976809  1.094838  1.336345  1.241150
# 3      0.400301  0.442286  0.496618  0.491440
# 4      0.295633  0.336040  0.384940  0.390658
# ...         ...       ...       ...       ...
# 60975  0.243609  0.287467  0.358562  0.334102
# 60976  0.136923  0.155786  0.183672  0.175266
# 60977  0.096203  0.123225  0.146554  0.136965
# 60978  0.086273  0.102099  0.110596  0.100532
# 60979  0.133427  0.164436  0.176147  0.164144
#
# [60980 rows x 29 columns]
