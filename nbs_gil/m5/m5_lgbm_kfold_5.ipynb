# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
from datetime import datetime, timedelta
import gc
import numpy as np, pandas as pd
import lightgbm as lgb
from pathlib import Path
from sklearn.model_selection import KFold, StratifiedKFold

# %%
from fastai.vision import *

# %%
pd.options.display.max_columns = 50

# %% [markdown]
# ## Setup the path

# %%
path = Path('/kaggle/m5_forecasting/')
assert(path.exists())

# %%
def ls(self):
    return list(self.iterdir())
setattr(Path, 'ls', ls)

# %%
path.ls()
# Out:
# [PosixPath('/kaggle/m5_forecasting/sales_train_validation.csv'),
#  PosixPath('/kaggle/m5_forecasting/m5_model_0.lgb'),
#  PosixPath('/kaggle/m5_forecasting/m5_model_1.lgb'),
#  PosixPath('/kaggle/m5_forecasting/m5_model_3.lgb'),
#  PosixPath('/kaggle/m5_forecasting/walmartTrends0.csv'),
#  PosixPath('/kaggle/m5_forecasting/m5_model_2.lgb'),
#  PosixPath('/kaggle/m5_forecasting/m5_model.lgb'),
#  PosixPath('/kaggle/m5_forecasting/calendar.csv'),
#  PosixPath('/kaggle/m5_forecasting/sample_submission.csv'),
#  PosixPath('/kaggle/m5_forecasting/m5_model_4.lgb'),
#  PosixPath('/kaggle/m5_forecasting/sell_prices.csv')]

# %% [markdown]
# ## Read Data

# %%
PRICE_DTYPES = {"store_id": "category", "item_id": "category", "wm_yr_wk": "int16","sell_price":"float32" }
CAL_DTYPES = {"event_name_2": "category", "event_type_1": "category", 
         "event_type_2": "category", "weekday": "category", 'wm_yr_wk': 'int16', "wday": "int16",
        "month": "int16", "year": "int16", "snap_CA": "float32", 'snap_TX': 'float32', 'snap_WI': 'float32' }

# %%
sales_train_validation = pd.read_csv(path/"sales_train_validation.csv", nrows=10)

# %%
def read_data():
    prices = pd.read_csv(path/"sell_prices.csv", dtype = PRICE_DTYPES)
    cal = pd.read_csv(path/"calendar.csv", dtype = CAL_DTYPES)
    walmart_trends = pd.read_csv(path/"walmartTrends0.csv")
    return prices, cal, walmart_trends

# %%
prices, cal, walmart_trends = read_data()

# %%
cal.head()
# Out:
#          date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011  d_1          NaN
# 1  2011-01-30     11101     Sunday     2      1  2011  d_2          NaN
# 2  2011-01-31     11101     Monday     3      1  2011  d_3          NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011  d_4          NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN      0.0      0.0      0.0
# 1          NaN          NaN          NaN      0.0      0.0      0.0
# 2          NaN          NaN          NaN      0.0      0.0      0.0
# 3          NaN          NaN          NaN      1.0      1.0      0.0
# 4          NaN          NaN          NaN      1.0      0.0      1.0

# %% [markdown]
# #### Pre-process calendar

# %%
cal["date"] = pd.to_datetime(cal["date"], infer_datetime_format=True)

# %%
cal['date'].min(), cal['date'].max()
# Out:
# (Timestamp('2011-01-29 00:00:00'), Timestamp('2016-06-19 00:00:00'))

# %%
cal.head(40)
# Out:
#          date  wm_yr_wk    weekday  wday  month  year     d   event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011   d_1            NaN
# 1  2011-01-30     11101     Sunday     2      1  2011   d_2            NaN
# 2  2011-01-31     11101     Monday     3      1  2011   d_3            NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011   d_4            NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011   d_5            NaN
# 5  2011-02-03     11101   Thursday     6      2  2011   d_6            NaN
# 6  2011-02-04     11101     Friday     7      2  2011   d_7            NaN
# 7  2011-02-05     11102   Saturday     1      2  2011   d_8            NaN
# 8  2011-02-06     11102     Sunday     2      2  2011   d_9      SuperBowl
# 9  2011-02-07     11102     Monday     3      2  2011  d_10            NaN
# 10 2011-02-08     11102    Tuesday     4      2  2011  d_11            NaN
# 11 2011-02-09     11102  Wednesday     5      2  2011  d_12            NaN
# 12 2011-02-10     11102   Thursday     6      2  2011  d_13            NaN
# 13 2011-02-11     11102     Friday     7      2  2011  d_14            NaN
# 14 2011-02-12     11103   Saturday     1      2  2011  d_15            NaN
# 15 2011-02-13     11103     Sunday     2      2  2011  d_16            NaN
# 16 2011-02-14     11103     Monday     3      2  2011  d_17  ValentinesDay
# 17 2011-02-15     11103    Tuesday     4      2  2011  d_18            NaN
# 18 2011-02-16     11103  Wednesday     5      2  2011  d_19            NaN
# 19 2011-02-17     11103   Thursday     6      2  2011  d_20            NaN
# 20 2011-02-18     11103     Friday     7      2  2011  d_21            NaN
# 21 2011-02-19     11104   Saturday     1      2  2011  d_22            NaN
# 22 2011-02-20     11104     Sunday     2      2  2011  d_23            NaN
# 23 2011-02-21     11104     Monday     3      2  2011  d_24  PresidentsDay
# 24 2011-02-22     11104    Tuesday     4      2  2011  d_25            NaN
# 25 2011-02-23     11104  Wednesday     5      2  2011  d_26            NaN
# 26 2011-02-24     11104   Thursday     6      2  2011  d_27            NaN
# 27 2011-02-25     11104     Friday     7      2  2011  d_28            NaN
# 28 2011-02-26     11105   Saturday     1      2  2011  d_29            NaN
# 29 2011-02-27     11105     Sunday     2      2  2011  d_30            NaN
# 30 2011-02-28     11105     Monday     3      2  2011  d_31            NaN
# 31 2011-03-01     11105    Tuesday     4      3  2011  d_32            NaN
# 32 2011-03-02     11105  Wednesday     5      3  2011  d_33            NaN
# 33 2011-03-03     11105   Thursday     6      3  2011  d_34            NaN
# 34 2011-03-04     11105     Friday     7      3  2011  d_35            NaN
# 35 2011-03-05     11106   Saturday     1      3  2011  d_36            NaN
# 36 2011-03-06     11106     Sunday     2      3  2011  d_37            NaN
# 37 2011-03-07     11106     Monday     3      3  2011  d_38            NaN
# 38 2011-03-08     11106    Tuesday     4      3  2011  d_39            NaN
# 39 2011-03-09     11106  Wednesday     5      3  2011  d_40      LentStart
#
#    event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0           NaN          NaN          NaN      0.0      0.0      0.0
# 1           NaN          NaN          NaN      0.0      0.0      0.0
# 2           NaN          NaN          NaN      0.0      0.0      0.0
# 3           NaN          NaN          NaN      1.0      1.0      0.0
# 4           NaN          NaN          NaN      1.0      0.0      1.0
# 5           NaN          NaN          NaN      1.0      1.0      1.0
# 6           NaN          NaN          NaN      1.0      0.0      0.0
# 7           NaN          NaN          NaN      1.0      1.0      1.0
# 8      Sporting          NaN          NaN      1.0      1.0      1.0
# 9           NaN          NaN          NaN      1.0      1.0      0.0
# 10          NaN          NaN          NaN      1.0      0.0      1.0
# 11          NaN          NaN          NaN      1.0      1.0      1.0
# 12          NaN          NaN          NaN      1.0      0.0      0.0
# 13          NaN          NaN          NaN      0.0      1.0      1.0
# 14          NaN          NaN          NaN      0.0      1.0      1.0
# 15          NaN          NaN          NaN      0.0      1.0      0.0
# 16     Cultural          NaN          NaN      0.0      0.0      1.0
# 17          NaN          NaN          NaN      0.0      1.0      1.0
# 18          NaN          NaN          NaN      0.0      0.0      0.0
# 19          NaN          NaN          NaN      0.0      0.0      0.0
# 20          NaN          NaN          NaN      0.0      0.0      0.0
# 21          NaN          NaN          NaN      0.0      0.0      0.0
# 22          NaN          NaN          NaN      0.0      0.0      0.0
# 23     National          NaN          NaN      0.0      0.0      0.0
# 24          NaN          NaN          NaN      0.0      0.0      0.0
# 25          NaN          NaN          NaN      0.0      0.0      0.0
# 26          NaN          NaN          NaN      0.0      0.0      0.0
# 27          NaN          NaN          NaN      0.0      0.0      0.0
# 28          NaN          NaN          NaN      0.0      0.0      0.0
# 29          NaN          NaN          NaN      0.0      0.0      0.0
# 30          NaN          NaN          NaN      0.0      0.0      0.0
# 31          NaN          NaN          NaN      1.0      1.0      0.0
# 32          NaN          NaN          NaN      1.0      0.0      1.0
# 33          NaN          NaN          NaN      1.0      1.0      1.0
# 34          NaN          NaN          NaN      1.0      0.0      0.0
# 35          NaN          NaN          NaN      1.0      1.0      1.0
# 36          NaN          NaN          NaN      1.0      1.0      1.0
# 37          NaN          NaN          NaN      1.0      1.0      0.0
# 38          NaN          NaN          NaN      1.0      0.0      1.0
# 39    Religious          NaN          NaN      1.0      1.0      1.0

# %%
def create_event_map(field):
    return {v: k for k, v in enumerate(cal[field].unique())}

# %%
event_name_1_map = create_event_map('event_name_1')
cal.replace({'event_name_1': event_name_1_map}, inplace=True)

# %%
event_name_1_map
# Out:
# {nan: 0,
#  'SuperBowl': 1,
#  'ValentinesDay': 2,
#  'PresidentsDay': 3,
#  'LentStart': 4,
#  'LentWeek2': 5,
#  'StPatricksDay': 6,
#  'Purim End': 7,
#  'OrthodoxEaster': 8,
#  'Pesach End': 9,
#  'Cinco De Mayo': 10,
#  "Mother's day": 11,
#  'MemorialDay': 12,
#  'NBAFinalsStart': 13,
#  'NBAFinalsEnd': 14,
#  "Father's day": 15,
#  'IndependenceDay': 16,
#  'Ramadan starts': 17,
#  'Eid al-Fitr': 18,
#  'LaborDay': 19,
#  'ColumbusDay': 20,
#  'Halloween': 21,
#  'EidAlAdha': 22,
#  'VeteransDay': 23,
#  'Thanksgiving': 24,
#  'Christmas': 25,
#  'Chanukah End': 26,
#  'NewYear': 27,
#  'OrthodoxChristmas': 28,
#  'MartinLutherKingDay': 29,
#  'Easter': 30}

# %%
def get_elapsed(dt, event_name='Christmas', col='event_name_1', event_map=event_name_1_map, before=False):
    dt.sort_values(['date'], ascending=[(not before)], inplace=True)
    day1 = np.timedelta64(1, 'D')
    last_date = np.datetime64()
    res = []
    event = event_map[event_name]
    for v,d in zip(dt[col].values, dt.date.values):
        if v == event:
            last_date = d
        elapsed = ((d-last_date).astype('timedelta64[D]') / day1)
        res.append(elapsed)
    field_name = f"{'before' if before else 'after'}_{event_name.lower().replace(' ', '_')}"
    dt[field_name] = res

# %%
# get_elapsed(cal, 'Christmas', 'event_name_1', event_name_1_map, False)
# get_elapsed(cal, 'Easter', 'event_name_1', event_name_1_map, False)

# %%
def numericalize(df, type_map):
    for col, col_dtype in type_map.items():
        if col_dtype == "category":
            df[col] = df[col].cat.codes.astype('int16')
            df[col] -= df[col].min()

# %%
numericalize(prices, PRICE_DTYPES)
numericalize(cal, CAL_DTYPES)

# %%
prices.head()
# Out:
#    store_id  item_id  wm_yr_wk  sell_price
# 0         0        0     11325        9.58
# 1         0        0     11326        9.58
# 2         0        0     11327        8.26
# 3         0        0     11328        8.26
# 4         0        0     11329        8.26

# %%
pred_days = 28
max_lags = pred_days * 2 + 1
print('max_lags', max_lags)
num_cols = [c for c in pd.read_csv(path/"sales_train_validation.csv", nrows=2).columns if c.find('d_') == 0]
tr_last = len(num_cols)
catcols = ['id', 'item_id', 'dept_id','store_id', 'cat_id', 'state_id']
# For more training data use a lower value
FIRST_DAY=350
# Out:
# max_lags 57

# %%
def read_dt(is_train = True, nrows = None, first_day = 1200):
    start_day = max(1 if is_train else tr_last - max_lags, first_day)
    print('start_day', start_day)
    dtype = {num: 'float32' for num in num_cols}
    dtype.update({cat: 'category' for cat in catcols if cat != 'id'})
    numcols = [f"d_{day}" for day in range(start_day,tr_last+1)]
    dt = pd.read_csv(path/"sales_train_validation.csv", nrows=nrows, usecols = catcols + numcols, dtype=dtype)
    for col in catcols:
        if col != 'id':
            dt[col] = dt[col].cat.codes.astype('int16')
            dt[col] -= dt[col].min()
    if not is_train:
        for day in range(tr_last + 1, tr_last + 1 + pred_days):
            dt[f'd_{day}'] = np.nan
            
    dt = dt.melt(id_vars=catcols, value_vars=[col for col in dt.columns if col.startswith("d_")], var_name='d', value_name='sales')
    dt = dt.merge(cal, on='d', copy=False)
    dt = dt.merge(prices, on=['store_id', 'item_id', 'wm_yr_wk'], copy=False)
    return dt

# %%
# %%time

dt = read_dt(first_day=FIRST_DAY)
# Out:
# start_day 350
# CPU times: user 13.3 s, sys: 2.4 s, total: 15.7 s
# Wall time: 15.9 s

# %%
dt.shape
# Out:
# (40718219, 22)

# %%
dt
# Out:
#                                      id  item_id  dept_id  store_id  cat_id  \
# 0         HOBBIES_1_002_CA_1_validation        1        0         0       0
# 1         HOBBIES_1_004_CA_1_validation        3        0         0       0
# 2         HOBBIES_1_005_CA_1_validation        4        0         0       0
# 3         HOBBIES_1_008_CA_1_validation        7        0         0       0
# 4         HOBBIES_1_009_CA_1_validation        8        0         0       0
# ...                                 ...      ...      ...       ...     ...
# 40718214    FOODS_3_825_WI_3_validation     3046        6         9       2
# 40718215    FOODS_3_826_WI_3_validation     3047        6         9       2
# 40718216    FOODS_3_826_WI_3_validation     3047        6         9       2
# 40718217    FOODS_3_827_WI_3_validation     3048        6         9       2
# 40718218    FOODS_3_827_WI_3_validation     3048        6         9       2
#
#           state_id       d  sales       date  wm_yr_wk  weekday  wday  month  \
# 0                0   d_350    0.0 2012-01-13     11150        0     7      1
# 1                0   d_350    2.0 2012-01-13     11150        0     7      1
# 2                0   d_350    0.0 2012-01-13     11150        0     7      1
# 3                0   d_350    0.0 2012-01-13     11150        0     7      1
# 4                0   d_350    2.0 2012-01-13     11150        0     7      1
# ...            ...     ...    ...        ...       ...      ...   ...    ...
# 40718214         2  d_1913    0.0 2016-04-24     11613        3     2      4
# 40718215         2  d_1912    1.0 2016-04-23     11613        2     1      4
# 40718216         2  d_1913    3.0 2016-04-24     11613        3     2      4
# 40718217         2  d_1912    0.0 2016-04-23     11613        2     1      4
# 40718218         2  d_1913    0.0 2016-04-24     11613        3     2      4
#
#           year  event_name_1  event_type_1  event_name_2  event_type_2  \
# 0         2012             0             0             0             0
# 1         2012             0             0             0             0
# 2         2012             0             0             0             0
# 3         2012             0             0             0             0
# 4         2012             0             0             0             0
# ...        ...           ...           ...           ...           ...
# 40718214  2016             0             0             0             0
# 40718215  2016             0             0             0             0
# 40718216  2016             0             0             0             0
# 40718217  2016             0             0             0             0
# 40718218  2016             0             0             0             0
#
#           snap_CA  snap_TX  snap_WI  sell_price
# 0             0.0      1.0      0.0        3.97
# 1             0.0      1.0      0.0        4.34
# 2             0.0      1.0      0.0        2.48
# 3             0.0      1.0      0.0        0.50
# 4             0.0      1.0      0.0        1.77
# ...           ...      ...      ...         ...
# 40718214      0.0      0.0      0.0        3.98
# 40718215      0.0      0.0      0.0        1.28
# 40718216      0.0      0.0      0.0        1.28
# 40718217      0.0      0.0      0.0        1.00
# 40718218      0.0      0.0      0.0        1.00
#
# [40718219 rows x 22 columns]

# %%
dt.date.min(), dt.date.max()
# Out:
# (Timestamp('2012-01-13 00:00:00'), Timestamp('2016-04-24 00:00:00'))

# %% [markdown]
# ## Create features

# %%
def create_features(dt):
    lags = [7, 28]
    lag_cols = [f'sales_lag_{lag}' for lag in lags]
    for lag, lag_col in zip(lags, lag_cols):
        dt[lag_col] = dt[['id', 'sales']].groupby('id')['sales'].shift(lag)
        
    for win in lags:
        for lag, lag_col in zip(lags, lag_cols):
            grouped = dt[['id', lag_col]].groupby('id')[lag_col]
            dt[f'rmean_{lag}_{win}'] = grouped.transform(lambda x : x.rolling(win).mean())

# %%
# %%time
create_features(dt)
# Out:
# CPU times: user 1min 28s, sys: 5.88 s, total: 1min 34s
# Wall time: 1min 34s

# %%
attr = ['Dayofyear','Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start']
# attr = []
date_features = {
    "wday": "weekday",
    "week": "weekofyear",
    "month": "month",
    "quarter": "quarter",
    "year": "year",
    "mday": "day"
}

for f in attr:
    date_features[f.lower()] = f.lower()
    
date_features
# Out:
# {'wday': 'weekday',
#  'week': 'weekofyear',
#  'month': 'month',
#  'quarter': 'quarter',
#  'year': 'year',
#  'mday': 'day',
#  'dayofyear': 'dayofyear',
#  'is_month_end': 'is_month_end',
#  'is_month_start': 'is_month_start',
#  'is_quarter_end': 'is_quarter_end',
#  'is_quarter_start': 'is_quarter_start',
#  'is_year_end': 'is_year_end',
#  'is_year_start': 'is_year_start'}

# %%
def prepare_date_cols(dt):
    for date_feature_name, date_feature_func in date_features.items():
        if date_feature_name in dt.columns:
            dt[date_feature_name] = dt[date_feature_name].astype('int16')
        else:
            dt[date_feature_name] = getattr(dt['date'].dt, date_feature_func).astype('int16')

# %%
# %%time
prepare_date_cols(dt)
# Out:
# CPU times: user 22 s, sys: 300 ms, total: 22.3 s
# Wall time: 22.3 s

# %%
dt.dropna(inplace = True)

# %%
dt
# Out:
#                                      id  item_id  dept_id  store_id  cat_id  \
# 869062    HOBBIES_1_002_CA_1_validation        1        0         0       0
# 869063    HOBBIES_1_002_CA_1_validation        1        0         0       0
# 869069    HOBBIES_1_004_CA_1_validation        3        0         0       0
# 869070    HOBBIES_1_004_CA_1_validation        3        0         0       0
# 869076    HOBBIES_1_005_CA_1_validation        4        0         0       0
# ...                                 ...      ...      ...       ...     ...
# 40718214    FOODS_3_825_WI_3_validation     3046        6         9       2
# 40718215    FOODS_3_826_WI_3_validation     3047        6         9       2
# 40718216    FOODS_3_826_WI_3_validation     3047        6         9       2
# 40718217    FOODS_3_827_WI_3_validation     3048        6         9       2
# 40718218    FOODS_3_827_WI_3_validation     3048        6         9       2
#
#           state_id       d  sales       date  wm_yr_wk  weekday  wday  month  \
# 869062           0   d_405    0.0 2012-03-08     11206        4     6      3
# 869063           0   d_406    0.0 2012-03-09     11206        0     7      3
# 869069           0   d_405    1.0 2012-03-08     11206        4     6      3
# 869070           0   d_406    2.0 2012-03-09     11206        0     7      3
# 869076           0   d_405    0.0 2012-03-08     11206        4     6      3
# ...            ...     ...    ...        ...       ...      ...   ...    ...
# 40718214         2  d_1913    0.0 2016-04-24     11613        3     2      4
# 40718215         2  d_1912    1.0 2016-04-23     11613        2     1      4
# 40718216         2  d_1913    3.0 2016-04-24     11613        3     2      4
# 40718217         2  d_1912    0.0 2016-04-23     11613        2     1      4
# 40718218         2  d_1913    0.0 2016-04-24     11613        3     2      4
#
#           year  event_name_1  event_type_1  event_name_2  event_type_2  \
# 869062    2012             7             3             0             0
# 869063    2012             0             0             0             0
# 869069    2012             7             3             0             0
# 869070    2012             0             0             0             0
# 869076    2012             7             3             0             0
# ...        ...           ...           ...           ...           ...
# 40718214  2016             0             0             0             0
# 40718215  2016             0             0             0             0
# 40718216  2016             0             0             0             0
# 40718217  2016             0             0             0             0
# 40718218  2016             0             0             0             0
#
#           snap_CA  snap_TX  snap_WI  sell_price  sales_lag_7  sales_lag_28  \
# 869062        1.0      0.0      1.0        3.97          0.0           0.0
# 869063        1.0      1.0      1.0        3.97          0.0           1.0
# 869069        1.0      0.0      1.0        4.34          3.0           2.0
# 869070        1.0      1.0      1.0        4.34          1.0           0.0
# 869076        1.0      0.0      1.0        2.98          0.0           0.0
# ...           ...      ...      ...         ...          ...           ...
# 40718214      0.0      0.0      0.0        3.98          0.0           1.0
# 40718215      0.0      0.0      0.0        1.28          0.0           2.0
# 40718216      0.0      0.0      0.0        1.28          1.0           4.0
# 40718217      0.0      0.0      0.0        1.00          0.0           0.0
# 40718218      0.0      0.0      0.0        1.00          0.0           5.0
#
#           rmean_7_7  rmean_28_7  rmean_7_28  rmean_28_28  week  quarter  mday  \
# 869062     0.000000    0.142857    0.214286     0.214286    10        1     8
# 869063     0.000000    0.142857    0.178571     0.250000    10        1     9
# 869069     1.857143    1.142857    1.392857     1.678571    10        1     8
# 869070     2.000000    1.000000    1.392857     1.607143    10        1     9
# 869076     0.000000    1.857143    0.750000     0.642857    10        1     8
# ...             ...         ...         ...          ...   ...      ...   ...
# 40718214   1.000000    0.714286    0.928571     1.250000    16        2    24
# 40718215   0.857143    1.142857    1.035714     1.107143    16        2    23
# 40718216   0.714286    1.571429    1.035714     1.250000    16        2    24
# 40718217   0.000000    2.285714    1.821429     1.785714    16        2    23
# 40718218   0.000000    2.428571    1.678571     1.964286    16        2    24
#
#           dayofyear  is_month_end  is_month_start  is_quarter_end  \
# 869062           68             0               0               0
# 869063           69             0               0               0
# 869069           68             0               0               0
# 869070           69             0               0               0
# 869076           68             0               0               0
# ...             ...           ...             ...             ...
# 40718214        115             0               0               0
# 40718215        114             0               0               0
# 40718216        115             0               0               0
# 40718217        114             0               0               0
# 40718218        115             0               0               0
#
#           is_quarter_start  is_year_end  is_year_start
# 869062                   0            0              0
# 869063                   0            0              0
# 869069                   0            0              0
# 869070                   0            0              0
# 869076                   0            0              0
# ...                    ...          ...            ...
# 40718214                 0            0              0
# 40718215                 0            0              0
# 40718216                 0            0              0
# 40718217                 0            0              0
# 40718218                 0            0              0
#
# [39041269 rows x 38 columns]

# %%
dt[dt.date == datetime(2014, 1, 1)].head(30)
# Out:
#                                      id  item_id  dept_id  store_id  cat_id  \
# 15789428  HOBBIES_1_001_CA_1_validation        0        0         0       0
# 15789435  HOBBIES_1_002_CA_1_validation        1        0         0       0
# 15789442  HOBBIES_1_004_CA_1_validation        3        0         0       0
# 15789449  HOBBIES_1_005_CA_1_validation        4        0         0       0
# 15789456  HOBBIES_1_006_CA_1_validation        5        0         0       0
# 15789463  HOBBIES_1_007_CA_1_validation        6        0         0       0
# 15789470  HOBBIES_1_008_CA_1_validation        7        0         0       0
# 15789477  HOBBIES_1_009_CA_1_validation        8        0         0       0
# 15789484  HOBBIES_1_010_CA_1_validation        9        0         0       0
# 15789491  HOBBIES_1_011_CA_1_validation       10        0         0       0
# 15789498  HOBBIES_1_012_CA_1_validation       11        0         0       0
# 15789505  HOBBIES_1_013_CA_1_validation       12        0         0       0
# 15789512  HOBBIES_1_014_CA_1_validation       13        0         0       0
# 15789519  HOBBIES_1_015_CA_1_validation       14        0         0       0
# 15789526  HOBBIES_1_016_CA_1_validation       15        0         0       0
# 15789533  HOBBIES_1_017_CA_1_validation       16        0         0       0
# 15789540  HOBBIES_1_018_CA_1_validation       17        0         0       0
# 15789547  HOBBIES_1_019_CA_1_validation       18        0         0       0
# 15789554  HOBBIES_1_020_CA_1_validation       19        0         0       0
# 15789561  HOBBIES_1_021_CA_1_validation       20        0         0       0
# 15789568  HOBBIES_1_022_CA_1_validation       21        0         0       0
# 15789575  HOBBIES_1_023_CA_1_validation       22        0         0       0
# 15789582  HOBBIES_1_024_CA_1_validation       23        0         0       0
# 15789589  HOBBIES_1_025_CA_1_validation       24        0         0       0
# 15789596  HOBBIES_1_028_CA_1_validation       27        0         0       0
# 15789603  HOBBIES_1_029_CA_1_validation       28        0         0       0
# 15789610  HOBBIES_1_030_CA_1_validation       29        0         0       0
# 15789617  HOBBIES_1_031_CA_1_validation       30        0         0       0
# 15789624  HOBBIES_1_032_CA_1_validation       31        0         0       0
# 15789631  HOBBIES_1_033_CA_1_validation       32        0         0       0
#
#           state_id       d  sales       date  wm_yr_wk  weekday  wday  month  \
# 15789428         0  d_1069    1.0 2014-01-01     11349        6     5      1
# 15789435         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 15789442         0  d_1069    2.0 2014-01-01     11349        6     5      1
# 15789449         0  d_1069    1.0 2014-01-01     11349        6     5      1
# 15789456         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 15789463         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 15789470         0  d_1069    3.0 2014-01-01     11349        6     5      1
# 15789477         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 15789484         0  d_1069    3.0 2014-01-01     11349        6     5      1
# 15789491         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 15789498         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 15789505         0  d_1069    1.0 2014-01-01     11349        6     5      1
# 15789512         0  d_1069    1.0 2014-01-01     11349        6     5      1
# 15789519         0  d_1069   14.0 2014-01-01     11349        6     5      1
# 15789526         0  d_1069    5.0 2014-01-01     11349        6     5      1
# 15789533         0  d_1069    2.0 2014-01-01     11349        6     5      1
# 15789540         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 15789547         0  d_1069    2.0 2014-01-01     11349        6     5      1
# 15789554         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 15789561         0  d_1069    2.0 2014-01-01     11349        6     5      1
# 15789568         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 15789575         0  d_1069    1.0 2014-01-01     11349        6     5      1
# 15789582         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 15789589         0  d_1069    1.0 2014-01-01     11349        6     5      1
# 15789596         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 15789603         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 15789610         0  d_1069    2.0 2014-01-01     11349        6     5      1
# 15789617         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 15789624         0  d_1069    0.0 2014-01-01     11349        6     5      1
# 15789631         0  d_1069    2.0 2014-01-01     11349        6     5      1
#
#           year  event_name_1  event_type_1  event_name_2  event_type_2  \
# 15789428  2014            27             2             0             0
# 15789435  2014            27             2             0             0
# 15789442  2014            27             2             0             0
# 15789449  2014            27             2             0             0
# 15789456  2014            27             2             0             0
# 15789463  2014            27             2             0             0
# 15789470  2014            27             2             0             0
# 15789477  2014            27             2             0             0
# 15789484  2014            27             2             0             0
# 15789491  2014            27             2             0             0
# 15789498  2014            27             2             0             0
# 15789505  2014            27             2             0             0
# 15789512  2014            27             2             0             0
# 15789519  2014            27             2             0             0
# 15789526  2014            27             2             0             0
# 15789533  2014            27             2             0             0
# 15789540  2014            27             2             0             0
# 15789547  2014            27             2             0             0
# 15789554  2014            27             2             0             0
# 15789561  2014            27             2             0             0
# 15789568  2014            27             2             0             0
# 15789575  2014            27             2             0             0
# 15789582  2014            27             2             0             0
# 15789589  2014            27             2             0             0
# 15789596  2014            27             2             0             0
# 15789603  2014            27             2             0             0
# 15789610  2014            27             2             0             0
# 15789617  2014            27             2             0             0
# 15789624  2014            27             2             0             0
# 15789631  2014            27             2             0             0
#
#           snap_CA  snap_TX  snap_WI  sell_price  sales_lag_7  sales_lag_28  \
# 15789428      1.0      1.0      0.0        8.26          0.0           1.0
# 15789435      1.0      1.0      0.0        3.97          0.0           0.0
# 15789442      1.0      1.0      0.0        4.64          0.0           1.0
# 15789449      1.0      1.0      0.0        3.08          0.0           1.0
# 15789456      1.0      1.0      0.0        1.00          0.0           1.0
# 15789463      1.0      1.0      0.0        7.88          0.0           0.0
# 15789470      1.0      1.0      0.0        0.46          0.0          11.0
# 15789477      1.0      1.0      0.0        1.77          0.0           1.0
# 15789484      1.0      1.0      0.0        2.97          0.0           2.0
# 15789491      1.0      1.0      0.0        3.48          0.0           0.0
# 15789498      1.0      1.0      0.0        6.52          0.0           0.0
# 15789505      1.0      1.0      0.0        1.97          0.0           0.0
# 15789512      1.0      1.0      0.0        0.98          0.0           3.0
# 15789519      1.0      1.0      0.0        0.70          0.0           0.0
# 15789526      1.0      1.0      0.0        0.70          0.0           0.0
# 15789533      1.0      1.0      0.0        1.98          0.0           4.0
# 15789540      1.0      1.0      0.0       11.88          0.0           0.0
# 15789547      1.0      1.0      0.0        0.46          0.0           7.0
# 15789554      1.0      1.0      0.0       12.68          0.0           0.0
# 15789561      1.0      1.0      0.0       11.88          0.0           1.0
# 15789568      1.0      1.0      0.0        7.18          0.0           2.0
# 15789575      1.0      1.0      0.0        3.44          0.0           1.0
# 15789582      1.0      1.0      0.0        8.98          0.0           0.0
# 15789589      1.0      1.0      0.0        3.98          0.0           1.0
# 15789596      1.0      1.0      0.0        7.98          0.0           2.0
# 15789603      1.0      1.0      0.0        8.98          0.0           0.0
# 15789610      1.0      1.0      0.0        0.70          0.0           5.0
# 15789617      1.0      1.0      0.0       10.98          0.0           1.0
# 15789624      1.0      1.0      0.0        0.58          0.0           0.0
# 15789631      1.0      1.0      0.0       15.97          0.0           0.0
#
#           rmean_7_7  rmean_28_7  rmean_7_28  rmean_28_28  week  quarter  mday  \
# 15789428   0.714286    1.000000    0.857143     0.714286     1        1     1
# 15789435   0.285714    0.000000    0.357143     0.071429     1        1     1
# 15789442   1.857143    3.142857    2.464286     2.107143     1        1     1
# 15789449   1.428571    1.000000    1.071429     0.750000     1        1     1
# 15789456   0.285714    0.714286    0.607143     1.035714     1        1     1
# 15789463   0.714286    0.142857    0.392857     0.392857     1        1     1
# 15789470   5.428571    5.714286    6.214286     8.250000     1        1     1
# 15789477   1.571429    1.285714    1.428571     1.464286     1        1     1
# 15789484   0.571429    1.142857    0.714286     0.785714     1        1     1
# 15789491   0.000000    0.000000    0.107143     0.107143     1        1     1
# 15789498   0.714286    0.428571    0.428571     0.607143     1        1     1
# 15789505   0.428571    0.428571    0.321429     0.500000     1        1     1
# 15789512   1.142857    1.714286    1.357143     1.428571     1        1     1
# 15789519  18.428572    9.285714   12.285714     7.500000     1        1     1
# 15789526   4.571429    9.428572    5.250000     4.857143     1        1     1
# 15789533   1.000000    1.285714    0.892857     1.607143     1        1     1
# 15789540   0.000000    0.000000    0.000000     0.000000     1        1     1
# 15789547  11.000000   12.142858    9.964286    11.464286     1        1     1
# 15789554   0.142857    0.285714    0.214286     0.142857     1        1     1
# 15789561   1.000000    0.857143    0.964286     0.821429     1        1     1
# 15789568   0.142857    0.285714    0.214286     0.500000     1        1     1
# 15789575   0.714286    0.714286    0.785714     0.857143     1        1     1
# 15789582   0.000000    0.428571    0.428571     0.285714     1        1     1
# 15789589   1.142857    0.571429    0.642857     0.464286     1        1     1
# 15789596   0.857143    1.142857    0.964286     0.892857     1        1     1
# 15789603   1.428571    2.285714    1.964286     1.642857     1        1     1
# 15789610   4.857143    4.142857    4.750000     4.535714     1        1     1
# 15789617   0.142857    0.285714    0.250000     0.464286     1        1     1
# 15789624   4.142857    5.428571    5.142857     4.178571     1        1     1
# 15789631   0.428571    0.142857    0.250000     0.142857     1        1     1
#
#           dayofyear  is_month_end  is_month_start  is_quarter_end  \
# 15789428          1             0               1               0
# 15789435          1             0               1               0
# 15789442          1             0               1               0
# 15789449          1             0               1               0
# 15789456          1             0               1               0
# 15789463          1             0               1               0
# 15789470          1             0               1               0
# 15789477          1             0               1               0
# 15789484          1             0               1               0
# 15789491          1             0               1               0
# 15789498          1             0               1               0
# 15789505          1             0               1               0
# 15789512          1             0               1               0
# 15789519          1             0               1               0
# 15789526          1             0               1               0
# 15789533          1             0               1               0
# 15789540          1             0               1               0
# 15789547          1             0               1               0
# 15789554          1             0               1               0
# 15789561          1             0               1               0
# 15789568          1             0               1               0
# 15789575          1             0               1               0
# 15789582          1             0               1               0
# 15789589          1             0               1               0
# 15789596          1             0               1               0
# 15789603          1             0               1               0
# 15789610          1             0               1               0
# 15789617          1             0               1               0
# 15789624          1             0               1               0
# 15789631          1             0               1               0
#
#           is_quarter_start  is_year_end  is_year_start
# 15789428                 1            0              1
# 15789435                 1            0              1
# 15789442                 1            0              1
# 15789449                 1            0              1
# 15789456                 1            0              1
# 15789463                 1            0              1
# 15789470                 1            0              1
# 15789477                 1            0              1
# 15789484                 1            0              1
# 15789491                 1            0              1
# 15789498                 1            0              1
# 15789505                 1            0              1
# 15789512                 1            0              1
# 15789519                 1            0              1
# 15789526                 1            0              1
# 15789533                 1            0              1
# 15789540                 1            0              1
# 15789547                 1            0              1
# 15789554                 1            0              1
# 15789561                 1            0              1
# 15789568                 1            0              1
# 15789575                 1            0              1
# 15789582                 1            0              1
# 15789589                 1            0              1
# 15789596                 1            0              1
# 15789603                 1            0              1
# 15789610                 1            0              1
# 15789617                 1            0              1
# 15789624                 1            0              1
# 15789631                 1            0              1

# %% [markdown]
# ## Training

# %%
dt.columns
# Out:
# Index(['id', 'item_id', 'dept_id', 'store_id', 'cat_id', 'state_id', 'd',
#        'sales', 'date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year',
#        'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2',
#        'snap_CA', 'snap_TX', 'snap_WI', 'sell_price', 'sales_lag_7',
#        'sales_lag_28', 'rmean_7_7', 'rmean_28_7', 'rmean_7_28', 'rmean_28_28',
#        'week', 'quarter', 'mday', 'dayofyear', 'is_month_end',
#        'is_month_start', 'is_quarter_end', 'is_quarter_start', 'is_year_end',
#        'is_year_start'],
#       dtype='object')

# %%
cat_feats = ['item_id', 'dept_id', 'store_id', 'cat_id', 'state_id', 'event_name_1', 
             'event_type_1', 'event_name_2', 'event_type_2']
ignore_cols = ['id', 'date', 'sales', 'd', 'wm_yr_wk', 'weekday']
train_cols = [c for c in dt.columns if c not in ignore_cols]
X = dt[train_cols]
Y = dt['sales']
num_splits = 5

# %%
del dt
gc.collect()
# Out:
# 80

# %%
lgb_params = {
        "objective" : "poisson",
        "learning_rate" : 0.08,
#         "sub_feature" : 0.8,
        "sub_row" : 0.75,
        "bagging_freq" : 1,
        "lambda_l2" : 0.1,
        "nthread" : 12,
        "metric": ["rmse"],
        'verbosity': 1,
        'num_leaves': 128,
        "min_data_in_leaf": 100,
}

# %%
# %%time

kf = KFold(n_splits=num_splits, shuffle=True)
models = []
for fold, (train_idx, valid_idx) in enumerate(kf.split(X)):
    print(f'Fold: {fold+1}')
    x_train, x_val = X.iloc[train_idx], X.iloc[valid_idx]
    y_train, y_val = Y.iloc[train_idx], Y.iloc[valid_idx]
    train_set = lgb.Dataset(x_train, y_train, categorical_feature=cat_feats)
    val_set = lgb.Dataset(x_val, y_val, categorical_feature=cat_feats)
    models.append(lgb.train(lgb_params, train_set, valid_sets=[train_set, val_set], verbose_eval=20, 
                             categorical_feature=cat_feats, num_boost_round=360))
# Out:
# Fold: 1
# [20]	training's rmse: 2.94778	valid_1's rmse: 2.93606
# [40]	training's rmse: 2.54996	valid_1's rmse: 2.56817
# [60]	training's rmse: 2.45532	valid_1's rmse: 2.48175
# [80]	training's rmse: 2.43033	valid_1's rmse: 2.45897
# [100]	training's rmse: 2.41864	valid_1's rmse: 2.4483
# [120]	training's rmse: 2.40495	valid_1's rmse: 2.43617
# [140]	training's rmse: 2.39534	valid_1's rmse: 2.42727
# [160]	training's rmse: 2.38476	valid_1's rmse: 2.41835
# [180]	training's rmse: 2.3735	valid_1's rmse: 2.40929
# [200]	training's rmse: 2.36389	valid_1's rmse: 2.40079
# [220]	training's rmse: 2.35674	valid_1's rmse: 2.39568
# [240]	training's rmse: 2.35002	valid_1's rmse: 2.39071
# [260]	training's rmse: 2.34326	valid_1's rmse: 2.38568
# [280]	training's rmse: 2.33592	valid_1's rmse: 2.37993
# [300]	training's rmse: 2.32911	valid_1's rmse: 2.37498
# [320]	training's rmse: 2.32213	valid_1's rmse: 2.37006
# [340]	training's rmse: 2.31721	valid_1's rmse: 2.36663
# [360]	training's rmse: 2.31113	valid_1's rmse: 2.36264
# Fold: 2
# [20]	training's rmse: 2.8778	valid_1's rmse: 2.92228
# [40]	training's rmse: 2.53668	valid_1's rmse: 2.56492
# [60]	training's rmse: 2.45717	valid_1's rmse: 2.48158
# [80]	training's rmse: 2.43329	valid_1's rmse: 2.45752
# [100]	training's rmse: 2.42	valid_1's rmse: 2.4456
# [120]	training's rmse: 2.40844	valid_1's rmse: 2.43456
# [140]	training's rmse: 2.39824	valid_1's rmse: 2.42546
# [160]	training's rmse: 2.38607	valid_1's rmse: 2.41487
# [180]	training's rmse: 2.37353	valid_1's rmse: 2.40301
# [200]	training's rmse: 2.36401	valid_1's rmse: 2.39507
# [220]	training's rmse: 2.35526	valid_1's rmse: 2.38842
# [240]	training's rmse: 2.34804	valid_1's rmse: 2.38278
# [260]	training's rmse: 2.3419	valid_1's rmse: 2.37839
# [280]	training's rmse: 2.33589	valid_1's rmse: 2.37363
# [300]	training's rmse: 2.33116	valid_1's rmse: 2.37043
# [320]	training's rmse: 2.32293	valid_1's rmse: 2.36431
# [340]	training's rmse: 2.31749	valid_1's rmse: 2.36081
# [360]	training's rmse: 2.3129	valid_1's rmse: 2.35816
# Fold: 3
# [20]	training's rmse: 2.87024	valid_1's rmse: 2.89212
# [40]	training's rmse: 2.53018	valid_1's rmse: 2.56936
# [60]	training's rmse: 2.44899	valid_1's rmse: 2.49582
# [80]	training's rmse: 2.42511	valid_1's rmse: 2.47676
# [100]	training's rmse: 2.41306	valid_1's rmse: 2.46772
# [120]	training's rmse: 2.3993	valid_1's rmse: 2.45652
# [140]	training's rmse: 2.38932	valid_1's rmse: 2.44887
# [160]	training's rmse: 2.37587	valid_1's rmse: 2.43832
# [180]	training's rmse: 2.36714	valid_1's rmse: 2.43209
# [200]	training's rmse: 2.35858	valid_1's rmse: 2.42515
# [220]	training's rmse: 2.35034	valid_1's rmse: 2.41898
# [240]	training's rmse: 2.34172	valid_1's rmse: 2.41233
# [260]	training's rmse: 2.33555	valid_1's rmse: 2.40797
# [280]	training's rmse: 2.32711	valid_1's rmse: 2.40211
# [300]	training's rmse: 2.32082	valid_1's rmse: 2.39819
# [320]	training's rmse: 2.31329	valid_1's rmse: 2.39353
# [340]	training's rmse: 2.30712	valid_1's rmse: 2.38918
# [360]	training's rmse: 2.30105	valid_1's rmse: 2.3847
# Fold: 4

# %%
# del X, Y, valid_idx, train_idx
# gc.collect()

# %%
for i, m_lgb in enumerate(models):
    m_lgb.save_model(str(path/f'm5_model_{i}.lgb'))

# %% [markdown]
# ## Prediction

# %%
from tqdm.notebook import tqdm

# %%
alphas = [1.028, 1.023, 1.018]
weights = [1 / len(alphas)] * len(alphas)
assert sum(weights) == 1.0
fday = datetime(2016, 4, 25) 
assert datetime(2011, 1, 29) + timedelta(days=1914 - 1) == fday

# %%
def run_predictions(models, df):
    y_pred = np.zeros((len(df), 1))
    print(y_pred.shape)
    for i, model in enumerate(models):
        y_pred += model.predict(df).reshape([len(df), 1])
    return y_pred / len(models)

# %%
cols = [f'F{i}' for i in range(1, pred_days + 1)]
sub = pd.DataFrame()
te = read_dt(False)

for icount, (alpha, weight) in tqdm(enumerate(zip(alphas, weights)), total=len(alphas)):
    for tdelta in tqdm(range(0, pred_days), total=pred_days):
        day = fday + timedelta(days=tdelta)
        print(tdelta, day)
        tst = te[(te.date >= day - timedelta(days=max_lags)) & (te.date <= day)].copy()
        create_features(tst)
        prepare_date_cols(tst)
        tst = tst.loc[tst.date == day, train_cols]
        prediction = run_predictions(models, tst)
        print('prediction.shape', prediction.shape)
        te.loc[te.date == day, 'sales'] = alpha * prediction # magic multiplier by kyakovlev
    
    te_sub = te.loc[te.date >= fday, ['id', 'sales']].copy()
    te_sub['F'] = [f"F{rank}" for rank in te_sub.groupby("id")["id"].cumcount()+1]
    te_sub = te_sub.set_index(["id", "F" ]).unstack()['sales'][cols]
    te_sub.fillna(0., inplace=True)
    te_sub.sort_values(["id"], inplace=True)
    te_sub.reset_index(drop=False, inplace = True)
    te_sub.to_csv(f"submission_{icount}.csv",index=False)
    
    if icount == 0:
        sub = te_sub
        sub[cols] *= weight
    else:
        sub[cols] += te_sub[cols] * weight

sub2 = sub.copy()
sub2["id"] = sub2["id"].str.replace("validation$", "evaluation")
sub = pd.concat([sub, sub2], axis=0, sort=False)
sub.to_csv("submission.csv",index=False)

# %%
# !wc -l submission.csv

# %%
pd.read_csv('submission.csv')
