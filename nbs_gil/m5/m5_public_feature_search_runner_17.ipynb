# %% [markdown]
# Run feature search multiple times

# %%
import numpy as np

# %%
# %%time

n_estimators = 1300
tweedie_variance_power = 1.28
sub_row = 0.75
bagging_freq = 1
learning_rate = 0.075

selected_features = ['id', 'item_id', 'dept_id', 'store_id', 'cat_id', 'state_id', 'd', 'sales', 'date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year', 'event_name_1', 
                     'event_type_1', 'event_name_2', 'event_type_2', 'snap_CA', 'snap_TX', 'snap_WI', 'before_christmas', 'sell_price', 
                     'Dayofyear', 'week', 'mday', 'lag_price_1', 'emean_7_1', 'esmean_7_1', 'emean_7_7', 'esmean_7_7', 'emean_7_28', 'esmean_7_28', 'emean_28_1', 
                     'esmean_28_1', 'emean_28_7', 'esmean_28_7', 'emean_28_28', 'esmean_28_28', 'lag_1', 'lag_2', 'expanding_mean_2_lag_1', 'ridge_predict']

for e in [500, 600, 700, 800, 900]:
#     random_feats = np.sort(np.random.choice(range(len(sales_features)), 12, replace = False))
#     rand_feats = [sales_features[i] for i, f in enumerate(sales_features) if i in random_feats]
    n_estimators = e
    print('selected_features', selected_features)
    # %run ./m5_lgbm_public_feature_search_16.ipynb
# Out:
# selected_features ['id', 'item_id', 'dept_id', 'store_id', 'cat_id', 'state_id', 'd', 'sales', 'date', 'wm_yr_wk', 'weekday', 'wday', 'month', 'year', 'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2', 'snap_CA', 'snap_TX', 'snap_WI', 'before_christmas', 'sell_price', 'Dayofyear', 'week', 'mday', 'lag_price_1', 'emean_7_1', 'esmean_7_1', 'emean_7_7', 'esmean_7_7', 'emean_7_28', 'esmean_7_28', 'emean_28_1', 'esmean_28_1', 'emean_28_7', 'esmean_28_7', 'emean_28_28', 'esmean_28_28', 'lag_1', 'lag_2', 'expanding_mean_2_lag_1', 'ridge_predict']
# CPU times: user 1.39 s, sys: 176 ms, total: 1.57 s
# Wall time: 1.57 s
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6579 entries, 0 to 6578
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        6579 non-null   uint16
#  1   month       6579 non-null   uint8
#  2   mday        6579 non-null   uint8
#  3   state_id    6579 non-null   uint8
# ...
