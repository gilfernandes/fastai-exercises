# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
path=Path('/kaggle/data_science_bowl')
path
# Out:
# PosixPath('/kaggle/data_science_bowl')

# %% [markdown]
# ### Read Data

# %%
def read_data():
    train_df = pd.read_csv(path/'train.csv')
    test_df = pd.read_csv(path/'test.csv')
    train_labels_df = pd.read_csv(path/'train_labels.csv')
    sample_submission_df = pd.read_csv(path/'sample_submission.csv')
    return train_df, test_df, train_labels_df, sample_submission_df

# %%
train_df, test_df, train_labels_df, sample_submission_df = read_data()

# %%
train_df.head()
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1  27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2  77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3  b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4  1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        0001e90f
# 1             {"event_code": 2000, "event_count": 1}        0001e90f
# 2  {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3  {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4  {"description":"Let's build a sandcastle! Firs...        0001e90f
#
#    event_count  event_code  game_time                          title  \
# 0            1        2000          0        Welcome to Lost Lagoon!
# 1            1        2000          0           Magma Peak - Level 1
# 2            1        2000          0  Sandcastle Builder (Activity)
# 3            2        3010         53  Sandcastle Builder (Activity)
# 4            3        3110       6972  Sandcastle Builder (Activity)
#
#        type      world
# 0      Clip       NONE
# 1      Clip  MAGMAPEAK
# 2  Activity  MAGMAPEAK
# 3  Activity  MAGMAPEAK
# 4  Activity  MAGMAPEAK

# %%
test_df.head()
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  0ea9ecc81a565215  2019-09-10T16:50:24.910Z
# 1  27253bdc  c1ea43d8b8261d27  2019-09-10T16:50:55.503Z
# 2  27253bdc  7ed86c6b72e725e2  2019-09-10T16:51:51.805Z
# 3  27253bdc  7e516ace50e7fe67  2019-09-10T16:53:12.825Z
# 4  7d093bf9  a022c3f60ba547e7  2019-09-10T16:54:12.115Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        00abaee7
# 1             {"event_code": 2000, "event_count": 1}        00abaee7
# 2             {"event_code": 2000, "event_count": 1}        00abaee7
# 3             {"event_code": 2000, "event_count": 1}        00abaee7
# 4  {"version":"1.0","round":0,"event_count":1,"ga...        00abaee7
#
#    event_count  event_code  game_time                    title  type  \
# 0            1        2000          0  Welcome to Lost Lagoon!  Clip
# 1            1        2000          0     Magma Peak - Level 1  Clip
# 2            1        2000          0     Magma Peak - Level 2  Clip
# 3            1        2000          0  Crystal Caves - Level 1  Clip
# 4            1        2000          0                Chow Time  Game
#
#           world
# 0          NONE
# 1     MAGMAPEAK
# 2     MAGMAPEAK
# 3  CRYSTALCAVES
# 4  CRYSTALCAVES

# %%
train_labels_df.head()
# Out:
#        game_session installation_id                         title  \
# 0  6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1  77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2  901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3  9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4  a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
#
#    num_correct  num_incorrect  accuracy  accuracy_group
# 0            1              0       1.0               3
# 1            0             11       0.0               0
# 2            1              0       1.0               3
# 3            1              1       0.5               2
# 4            1              0       1.0               3

# %%
sample_submission_df.head()
# Out:
#   installation_id  accuracy_group
# 0        00abaee7               3
# 1        01242218               3
# 2        017c5718               3
# 3        01a44906               3
# 4        01bc6cb6               3

# %%
sample_submission_df.groupby(['installation_id'])[['installation_id']].count()
# Out:
#                  installation_id
# installation_id
# 00abaee7                       1
# 01242218                       1
# 017c5718                       1
# 01a44906                       1
# 01bc6cb6                       1
# ...                          ...
# fee254cf                       1
# ff57e602                       1
# ffc73fb2                       1
# ffe00ca8                       1
# ffe774cc                       1
#
# [1000 rows x 1 columns]

# %%
sample_session = '6bdf9623adc94d89'

# %%
train_labels_df[train_labels_df['game_session'] == sample_session]
# Out:
#        game_session installation_id                         title  \
# 0  6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
#
#    num_correct  num_incorrect  accuracy  accuracy_group
# 0            1              0       1.0               3

# %%
train_df[train_df['game_session'] == sample_session]
# Out:
#       event_id      game_session                 timestamp  \
# 2768  3bfd1a65  6bdf9623adc94d89  2019-08-06T05:37:50.020Z
# 2769  db02c830  6bdf9623adc94d89  2019-08-06T05:37:50.078Z
# 2770  a1e4395d  6bdf9623adc94d89  2019-08-06T05:37:50.082Z
# 2771  7da34a02  6bdf9623adc94d89  2019-08-06T05:37:52.799Z
# 2772  28ed704e  6bdf9623adc94d89  2019-08-06T05:37:53.631Z
# 2773  a52b92d5  6bdf9623adc94d89  2019-08-06T05:37:53.632Z
# 2774  9d29771f  6bdf9623adc94d89  2019-08-06T05:37:53.635Z
# 2775  c74f40cd  6bdf9623adc94d89  2019-08-06T05:37:54.253Z
# 2776  28ed704e  6bdf9623adc94d89  2019-08-06T05:37:54.930Z
# 2777  9d29771f  6bdf9623adc94d89  2019-08-06T05:37:54.934Z
# 2778  c74f40cd  6bdf9623adc94d89  2019-08-06T05:37:55.464Z
# 2779  28ed704e  6bdf9623adc94d89  2019-08-06T05:37:56.000Z
# 2780  9d29771f  6bdf9623adc94d89  2019-08-06T05:37:56.003Z
# 2781  3dfd4aa4  6bdf9623adc94d89  2019-08-06T05:37:56.693Z
# 2782  83c6c409  6bdf9623adc94d89  2019-08-06T05:37:56.693Z
# 2783  c74f40cd  6bdf9623adc94d89  2019-08-06T05:37:56.693Z
# 2784  a1e4395d  6bdf9623adc94d89  2019-08-06T05:37:56.697Z
# 2785  7da34a02  6bdf9623adc94d89  2019-08-06T05:37:58.885Z
# 2786  7da34a02  6bdf9623adc94d89  2019-08-06T05:37:59.759Z
# 2787  7da34a02  6bdf9623adc94d89  2019-08-06T05:38:00.706Z
# 2788  a52b92d5  6bdf9623adc94d89  2019-08-06T05:38:00.716Z
# 2789  7da34a02  6bdf9623adc94d89  2019-08-06T05:38:01.621Z
# 2790  fbaf3456  6bdf9623adc94d89  2019-08-06T05:38:02.273Z
# 2791  5f0eb72c  6bdf9623adc94d89  2019-08-06T05:38:03.621Z
# 2792  fbaf3456  6bdf9623adc94d89  2019-08-06T05:38:04.420Z
# 2793  5f0eb72c  6bdf9623adc94d89  2019-08-06T05:38:05.265Z
# 2794  fbaf3456  6bdf9623adc94d89  2019-08-06T05:38:05.766Z
# 2795  5f0eb72c  6bdf9623adc94d89  2019-08-06T05:38:06.823Z
# 2796  a1e4395d  6bdf9623adc94d89  2019-08-06T05:38:06.826Z
# 2797  25fa8af4  6bdf9623adc94d89  2019-08-06T05:38:08.036Z
# 2798  a52b92d5  6bdf9623adc94d89  2019-08-06T05:38:08.039Z
# 2799  9d29771f  6bdf9623adc94d89  2019-08-06T05:38:08.040Z
# 2800  c74f40cd  6bdf9623adc94d89  2019-08-06T05:38:12.223Z
# 2801  6c930e6e  6bdf9623adc94d89  2019-08-06T05:38:12.836Z
# 2802  a5be6304  6bdf9623adc94d89  2019-08-06T05:38:16.835Z
#
#                                              event_data installation_id  \
# 2768  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 2769  {"event_count":2,"game_time":77,"event_code":2...        0006a69f
# 2770  {"description":"Pull three mushrooms out of th...        0006a69f
# 2771  {"coordinates":{"x":199,"y":484,"stage_width":...        0006a69f
# 2772  {"height":1,"coordinates":{"x":171,"y":519,"st...        0006a69f
# 2773  {"description":"Pull three mushrooms out of th...        0006a69f
# 2774  {"description":"That's one!","identifier":"Dot...        0006a69f
# 2775  {"description":"That's one!","identifier":"Dot...        0006a69f
# 2776  {"height":2,"coordinates":{"x":496,"y":502,"st...        0006a69f
# 2777  {"description":"two...","identifier":"Dot_Two"...        0006a69f
# 2778  {"description":"two...","identifier":"Dot_Two"...        0006a69f
# 2779  {"height":4,"coordinates":{"x":327,"y":543,"st...        0006a69f
# 2780  {"description":"and three!","identifier":"Dot_...        0006a69f
# 2781  {"event_count":16,"game_time":6692,"event_code...        0006a69f
# 2782  {"duration":6615,"event_count":15,"game_time":...        0006a69f
# 2783  {"description":"and three!","identifier":"Dot_...        0006a69f
# 2784  {"description":"Now order these mushrooms by h...        0006a69f
# 2785  {"coordinates":{"x":323,"y":534,"stage_width":...        0006a69f
# 2786  {"coordinates":{"x":333,"y":551,"stage_width":...        0006a69f
# 2787  {"coordinates":{"x":328,"y":534,"stage_width":...        0006a69f
# 2788  {"description":"Now order these mushrooms by h...        0006a69f
# 2789  {"coordinates":{"x":290,"y":536,"stage_width":...        0006a69f
# 2790  {"height":4,"stumps":[0,0,0],"coordinates":{"x...        0006a69f
# 2791  {"height":4,"destination":"right","stumps":[0,...        0006a69f
# 2792  {"height":2,"stumps":[0,0,4],"coordinates":{"x...        0006a69f
# 2793  {"height":2,"destination":"middle","stumps":[0...        0006a69f
# 2794  {"height":1,"stumps":[0,2,4],"coordinates":{"x...        0006a69f
# 2795  {"height":1,"destination":"left","stumps":[1,2...        0006a69f
# 2796  {"description":"Okay, when you want to check y...        0006a69f
# 2797  {"correct":true,"stumps":[1,2,4],"event_count"...        0006a69f
# 2798  {"description":"Okay, when you want to check y...        0006a69f
# 2799  {"description":"Alright! This one is the littl...        0006a69f
# 2800  {"description":"Alright! This one is the littl...        0006a69f
# 2801  {"duration":16126,"misses":0,"event_count":34,...        0006a69f
# 2802  {"session_duration":26827,"exit_type":"game_co...        0006a69f
#
#       event_count  event_code  game_time                         title  \
# 2768            1        2000          0  Mushroom Sorter (Assessment)
# 2769            2        2025         77  Mushroom Sorter (Assessment)
# 2770            3        3010         77  Mushroom Sorter (Assessment)
# 2771            4        4070       2784  Mushroom Sorter (Assessment)
# 2772            5        4025       3625  Mushroom Sorter (Assessment)
# 2773            6        3110       3625  Mushroom Sorter (Assessment)
# 2774            7        3021       3625  Mushroom Sorter (Assessment)
# 2775            8        3121       4250  Mushroom Sorter (Assessment)
# 2776            9        4025       4925  Mushroom Sorter (Assessment)
# 2777           10        3021       4925  Mushroom Sorter (Assessment)
# 2778           11        3121       5459  Mushroom Sorter (Assessment)
# 2779           12        4025       6000  Mushroom Sorter (Assessment)
# 2780           13        3021       6000  Mushroom Sorter (Assessment)
# 2781           16        2020       6692  Mushroom Sorter (Assessment)
# 2782           15        2035       6692  Mushroom Sorter (Assessment)
# 2783           14        3121       6692  Mushroom Sorter (Assessment)
# 2784           17        3010       6692  Mushroom Sorter (Assessment)
# 2785           18        4070       8876  Mushroom Sorter (Assessment)
# 2786           19        4070       9742  Mushroom Sorter (Assessment)
# 2787           20        4070      10692  Mushroom Sorter (Assessment)
# 2788           21        3110      10692  Mushroom Sorter (Assessment)
# 2789           22        4070      11601  Mushroom Sorter (Assessment)
# 2790           23        4030      12251  Mushroom Sorter (Assessment)
# 2791           24        4020      13618  Mushroom Sorter (Assessment)
# 2792           25        4030      14401  Mushroom Sorter (Assessment)
# 2793           26        4020      15259  Mushroom Sorter (Assessment)
# 2794           27        4030      15743  Mushroom Sorter (Assessment)
# 2795           28        4020      16826  Mushroom Sorter (Assessment)
# 2796           29        3010      16826  Mushroom Sorter (Assessment)
# 2797           30        4100      18026  Mushroom Sorter (Assessment)
# 2798           31        3110      18026  Mushroom Sorter (Assessment)
# 2799           32        3021      18026  Mushroom Sorter (Assessment)
# 2800           33        3121      22218  Mushroom Sorter (Assessment)
# 2801           34        2030      22818  Mushroom Sorter (Assessment)
# 2802           35        2010      26827  Mushroom Sorter (Assessment)
#
#             type        world
# 2768  Assessment  TREETOPCITY
# 2769  Assessment  TREETOPCITY
# 2770  Assessment  TREETOPCITY
# 2771  Assessment  TREETOPCITY
# 2772  Assessment  TREETOPCITY
# 2773  Assessment  TREETOPCITY
# 2774  Assessment  TREETOPCITY
# 2775  Assessment  TREETOPCITY
# 2776  Assessment  TREETOPCITY
# 2777  Assessment  TREETOPCITY
# 2778  Assessment  TREETOPCITY
# 2779  Assessment  TREETOPCITY
# 2780  Assessment  TREETOPCITY
# 2781  Assessment  TREETOPCITY
# 2782  Assessment  TREETOPCITY
# 2783  Assessment  TREETOPCITY
# 2784  Assessment  TREETOPCITY
# 2785  Assessment  TREETOPCITY
# 2786  Assessment  TREETOPCITY
# 2787  Assessment  TREETOPCITY
# 2788  Assessment  TREETOPCITY
# 2789  Assessment  TREETOPCITY
# 2790  Assessment  TREETOPCITY
# 2791  Assessment  TREETOPCITY
# 2792  Assessment  TREETOPCITY
# 2793  Assessment  TREETOPCITY
# 2794  Assessment  TREETOPCITY
# 2795  Assessment  TREETOPCITY
# 2796  Assessment  TREETOPCITY
# 2797  Assessment  TREETOPCITY
# 2798  Assessment  TREETOPCITY
# 2799  Assessment  TREETOPCITY
# 2800  Assessment  TREETOPCITY
# 2801  Assessment  TREETOPCITY
# 2802  Assessment  TREETOPCITY

# %% [markdown]
# ### Feature Engineering

# %%
import functools

class FeatureEngineering():
    
    def __init__(self, train_df, test_df, train_labels_df):
        self.train_df, self.test_df, self.train_labels_df = self.extract_time_features(train_df), self.extract_time_features(test_df), train_labels_df
        self.numerical_columns = ['game_time']
        self.categorical_columns = ['type', 'world']
        self.comp_train_df = self.create_unique_installation_id_df(train_df)
        self.comp_test_df = self.create_unique_installation_id_df(test_df)
        self.agg_operations = ['mean', 'sum', 'min', 'max', 'std', 'skew']
        merge_args = {'left_index':True, 'right_index':True}
        for col in self.numerical_columns:
            self.comp_train_df = self.comp_train_df.merge(self.get_aggregates(self.train_df, col), **merge_args)
            self.comp_test_df = self.comp_test_df.merge(self.get_aggregates(self.test_df, col), **merge_args)
            
        for col in self.categorical_columns:
            self.comp_train_df = self.comp_train_df.merge(self.get_object_columns(self.train_df, col), **merge_args)
            self.comp_test_df = self.comp_test_df.merge(self.get_object_columns(self.test_df, col), **merge_args)
            
        for col in self.categorical_columns:
            self.comp_train_df = self.comp_train_df.merge(
                self.get_numeric_columns_add(self.train_df, col, 'game_time'), **merge_args)
            self.comp_test_df = self.comp_test_df.merge(
                self.get_numeric_columns_add(self.test_df, col, 'game_time'), **merge_args)
            
        self.comp_train_df.reset_index()
        self.comp_test_df.reset_index()
        
        # mode of the title
        labels_map = dict(train_labels_df.groupby('title')['accuracy_group'].agg(lambda x:x.value_counts().index[0]))
        labels = train_labels_df[['installation_id', 'title', 'accuracy_group']]
        labels['title'] = labels['title'].map(labels_map)
        # get title from the test set
        self.comp_test_df['title'] = test_df.groupby('installation_id').last()['title'].map(labels_map).reset_index(drop = True).values
        self.comp_train_df = labels.merge(self.comp_train_df, on = 'installation_id', how = 'left')
        
        
    def create_unique_installation_id_df(self, df):
        comp_df = pd.DataFrame({'installation_id': df['installation_id'].unique()})
        comp_df.set_index('installation_id', inplace = True)
        return comp_df
    
    def extract_time_features(self, df):
        df['timestamp'] = pd.to_datetime(df['timestamp'])
        df['date'] = df['timestamp'].dt.date
        df['month'] = df['timestamp'].dt.month
        df['hour'] = df['timestamp'].dt.hour
        df['year'] = df['timestamp'].dt.year
        df['dayofweek'] = df['timestamp'].dt.dayofweek
        df['weekofyear'] = df['timestamp'].dt.weekofyear
        df['dayofyear'] = df['timestamp'].dt.dayofyear
        df['quarter'] = df['timestamp'].dt.quarter
        df['is_month_start'] = df['timestamp'].dt.is_month_start    
        return df
    
    def get_aggregates(self, df: pd.DataFrame, column):
        df_agg = df.groupby('installation_id').agg({column: self.agg_operations})
        df_agg[column].fillna(df_agg[column].mean(), inplace=True)
        df_agg.columns = [f'{column}_{c}' for c in self.agg_operations]
        return df_agg
    
    def get_object_columns(self, df, col):
        df = df.groupby(['installation_id', col])['event_id'].count().reset_index()
        df = df.pivot_table(index = 'installation_id', columns = [col], values = 'event_id')
        df.columns = list(df.columns)
        df.fillna(0, inplace = True)
        return df
    
    def get_numeric_columns_add(self, df, agg_column, column):
        df = df.groupby(['installation_id', agg_column]).agg({f'{column}': self.agg_operations}).reset_index()
        df = df.pivot_table(index = 'installation_id', columns = [agg_column], values = [col for col in df.columns if col not in ['installation_id', agg_column]])
        df[column].fillna(df[column].mean(), inplace = True)
        df.columns = list(df.columns)
        return df
        
    @property
    def comp_train_head(self):
        return self.comp_train_df[:10]
    
    @property
    def comp_test_head(self):
        return self.comp_test_df[:10]

    @property
    def comp_train_shape(self):
        return self.comp_train_df.shape
    
    @property
    def comp_test_shape(self):
        return self.comp_test_df.shape
    
    @property
    def comp_train_x(self):
        return self.comp_train_df[[i for i in self.comp_train_df.columns if i not in ['accuracy_group', 'installation_id']]]
    
    @property
    def comp_train_y(self):
        return self.comp_train_df['accuracy_group']
    
    @property
    def comp_train_ds(self):
        m = comp_train_y.size
        x_size = int(m * 0.8)
        return comp_train_x[:x_size], comp_train_y[:x_size], comp_train_x[x_size:], comp_train_y[x_size:]

# %%
from torch.utils.data import DataLoader, Dataset, SequentialSampler, RandomSampler
import torch

def convert_df_to_tensor(df):
    return torch.tensor(df.values)

class BowlDataSet(Dataset):
    def __init__(self, df_x: pd.DataFrame, df_y: pd.DataFrame):
        self.x = convert_df_to_tensor(df_x)
        self.y = convert_df_to_tensor(df_y)
        
    def __len__(self):
        return len(self.x)
    
    def __getitem__(self, i):
        return self.x[i], self.y[i]

# %%
feature_engineering = FeatureEngineering(train_df, test_df, train_labels_df)
# Out:
# /opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
comp_train_ds = feature_engineering.comp_train_ds
train_ds = BowlDataSet(comp_train_ds[0], comp_train_ds[1])
valid_ds = BowlDataSet(comp_train_ds[2], comp_train_ds[3])

# %%
len(train_ds), len(valid_ds), train_ds[0][1]
# Out:
# (14152, 3538, tensor(3))

# %%
comp_train_x = feature_engineering.comp_train_x

# %%
comp_train_x.head()
# Out:
#    title  game_time_mean  game_time_sum  game_time_min  game_time_max  \
# 0      3    82491.007366      313548319              0        1520600
# 1      0    82491.007366      313548319              0        1520600
# 2      3    82491.007366      313548319              0        1520600
# 3      3    82491.007366      313548319              0        1520600
# 4      0    82491.007366      313548319              0        1520600
#
#    game_time_std  game_time_skew  Activity  Assessment  Clip  ...  \
# 0  159789.192183        7.504204    1771.0       261.0  37.0  ...
# 1  159789.192183        7.504204    1771.0       261.0  37.0  ...
# 2  159789.192183        7.504204    1771.0       261.0  37.0  ...
# 3  159789.192183        7.504204    1771.0       261.0  37.0  ...
# 4  159789.192183        7.504204    1771.0       261.0  37.0  ...
#
#    (game_time, skew, NONE)  (game_time, skew, TREETOPCITY)  \
# 0                      0.0                        5.704184
# 1                      0.0                        5.704184
# 2                      0.0                        5.704184
# 3                      0.0                        5.704184
# 4                      0.0                        5.704184
#
#    (game_time, std, CRYSTALCAVES)  (game_time, std, MAGMAPEAK)  \
# 0                   115847.423107                 57216.164087
# 1                   115847.423107                 57216.164087
# 2                   115847.423107                 57216.164087
# 3                   115847.423107                 57216.164087
# 4                   115847.423107                 57216.164087
#
#    (game_time, std, NONE)  (game_time, std, TREETOPCITY)  \
# 0                     0.0                  217683.232366
# 1                     0.0                  217683.232366
# 2                     0.0                  217683.232366
# 3                     0.0                  217683.232366
# 4                     0.0                  217683.232366
#
#    (game_time, sum, CRYSTALCAVES)  (game_time, sum, MAGMAPEAK)  \
# 0                    6.031041e+07                  121568696.0
# 1                    6.031041e+07                  121568696.0
# 2                    6.031041e+07                  121568696.0
# 3                    6.031041e+07                  121568696.0
# 4                    6.031041e+07                  121568696.0
#
#    (game_time, sum, NONE)  (game_time, sum, TREETOPCITY)
# 0                     0.0                    191979623.0
# 1                     0.0                    191979623.0
# 2                     0.0                    191979623.0
# 3                     0.0                    191979623.0
# 4                     0.0                    191979623.0
#
# [5 rows x 63 columns]

# %%
comp_train_y = feature_engineering.comp_train_y

# %%
comp_train_y[:10].values
# Out:
# array([3, 0, 3, 2, 3, 3, 2, 0, 3, 0])

# %%
feature_engineering.comp_train_df.columns
# Out:
# Index([                    'installation_id',
#                                      'title',
#                             'accuracy_group',
#                             'game_time_mean',
#                              'game_time_sum',
#                              'game_time_min',
#                              'game_time_max',
#                              'game_time_std',
#                             'game_time_skew',
#                                   'Activity',
#                                 'Assessment',
#                                       'Clip',
#                                       'Game',
#                               'CRYSTALCAVES',
#                                  'MAGMAPEAK',
#                                       'NONE',
#                                'TREETOPCITY',
#             ('game_time', 'max', 'Activity'),
#           ('game_time', 'max', 'Assessment'),
#                 ('game_time', 'max', 'Clip'),
#                 ('game_time', 'max', 'Game'),
#            ('game_time', 'mean', 'Activity'),
#          ('game_time', 'mean', 'Assessment'),
#                ('game_time', 'mean', 'Clip'),
#                ('game_time', 'mean', 'Game'),
#             ('game_time', 'min', 'Activity'),
#           ('game_time', 'min', 'Assessment'),
#                 ('game_time', 'min', 'Clip'),
#                 ('game_time', 'min', 'Game'),
#            ('game_time', 'skew', 'Activity'),
#          ('game_time', 'skew', 'Assessment'),
#                ('game_time', 'skew', 'Clip'),
#                ('game_time', 'skew', 'Game'),
#             ('game_time', 'std', 'Activity'),
#           ('game_time', 'std', 'Assessment'),
#                 ('game_time', 'std', 'Clip'),
#                 ('game_time', 'std', 'Game'),
#             ('game_time', 'sum', 'Activity'),
#           ('game_time', 'sum', 'Assessment'),
#                 ('game_time', 'sum', 'Clip'),
#                 ('game_time', 'sum', 'Game'),
#         ('game_time', 'max', 'CRYSTALCAVES'),
#            ('game_time', 'max', 'MAGMAPEAK'),
#                 ('game_time', 'max', 'NONE'),
#          ('game_time', 'max', 'TREETOPCITY'),
#        ('game_time', 'mean', 'CRYSTALCAVES'),
#           ('game_time', 'mean', 'MAGMAPEAK'),
#                ('game_time', 'mean', 'NONE'),
#         ('game_time', 'mean', 'TREETOPCITY'),
#         ('game_time', 'min', 'CRYSTALCAVES'),
#            ('game_time', 'min', 'MAGMAPEAK'),
#                 ('game_time', 'min', 'NONE'),
#          ('game_time', 'min', 'TREETOPCITY'),
#        ('game_time', 'skew', 'CRYSTALCAVES'),
#           ('game_time', 'skew', 'MAGMAPEAK'),
#                ('game_time', 'skew', 'NONE'),
#         ('game_time', 'skew', 'TREETOPCITY'),
#         ('game_time', 'std', 'CRYSTALCAVES'),
#            ('game_time', 'std', 'MAGMAPEAK'),
#                 ('game_time', 'std', 'NONE'),
#          ('game_time', 'std', 'TREETOPCITY'),
#         ('game_time', 'sum', 'CRYSTALCAVES'),
#            ('game_time', 'sum', 'MAGMAPEAK'),
#                 ('game_time', 'sum', 'NONE'),
#          ('game_time', 'sum', 'TREETOPCITY')],
#       dtype='object')

# %%
feature_engineering.comp_test_df.columns
# Out:
# Index([                     'game_time_mean',
#                              'game_time_sum',
#                              'game_time_min',
#                              'game_time_max',
#                              'game_time_std',
#                             'game_time_skew',
#                                   'Activity',
#                                 'Assessment',
#                                       'Clip',
#                                       'Game',
#                               'CRYSTALCAVES',
#                                  'MAGMAPEAK',
#                                       'NONE',
#                                'TREETOPCITY',
#             ('game_time', 'max', 'Activity'),
#           ('game_time', 'max', 'Assessment'),
#                 ('game_time', 'max', 'Clip'),
#                 ('game_time', 'max', 'Game'),
#            ('game_time', 'mean', 'Activity'),
#          ('game_time', 'mean', 'Assessment'),
#                ('game_time', 'mean', 'Clip'),
#                ('game_time', 'mean', 'Game'),
#             ('game_time', 'min', 'Activity'),
#           ('game_time', 'min', 'Assessment'),
#                 ('game_time', 'min', 'Clip'),
#                 ('game_time', 'min', 'Game'),
#            ('game_time', 'skew', 'Activity'),
#          ('game_time', 'skew', 'Assessment'),
#                ('game_time', 'skew', 'Clip'),
#                ('game_time', 'skew', 'Game'),
#             ('game_time', 'std', 'Activity'),
#           ('game_time', 'std', 'Assessment'),
#                 ('game_time', 'std', 'Clip'),
#                 ('game_time', 'std', 'Game'),
#             ('game_time', 'sum', 'Activity'),
#           ('game_time', 'sum', 'Assessment'),
#                 ('game_time', 'sum', 'Clip'),
#                 ('game_time', 'sum', 'Game'),
#         ('game_time', 'max', 'CRYSTALCAVES'),
#            ('game_time', 'max', 'MAGMAPEAK'),
#                 ('game_time', 'max', 'NONE'),
#          ('game_time', 'max', 'TREETOPCITY'),
#        ('game_time', 'mean', 'CRYSTALCAVES'),
#           ('game_time', 'mean', 'MAGMAPEAK'),
#                ('game_time', 'mean', 'NONE'),
#         ('game_time', 'mean', 'TREETOPCITY'),
#         ('game_time', 'min', 'CRYSTALCAVES'),
#            ('game_time', 'min', 'MAGMAPEAK'),
#                 ('game_time', 'min', 'NONE'),
#          ('game_time', 'min', 'TREETOPCITY'),
#        ('game_time', 'skew', 'CRYSTALCAVES'),
#           ('game_time', 'skew', 'MAGMAPEAK'),
#                ('game_time', 'skew', 'NONE'),
#         ('game_time', 'skew', 'TREETOPCITY'),
#         ('game_time', 'std', 'CRYSTALCAVES'),
#            ('game_time', 'std', 'MAGMAPEAK'),
#                 ('game_time', 'std', 'NONE'),
#          ('game_time', 'std', 'TREETOPCITY'),
#         ('game_time', 'sum', 'CRYSTALCAVES'),
#            ('game_time', 'sum', 'MAGMAPEAK'),
#                 ('game_time', 'sum', 'NONE'),
#          ('game_time', 'sum', 'TREETOPCITY'),
#                                      'title'],
#       dtype='object')

# %%
feature_engineering.comp_train_df.groupby(['installation_id', 'title'])[['installation_id']].count()
# Out:
#                        installation_id
# installation_id title
# 0006a69f        0                    2
#                 3                    3
# 0006c192        0                    1
#                 3                    2
# 00129856        0                    1
# ...                                ...
# ff9715db        3                    7
# ffc90c32        0                    2
#                 3                    4
# ffd2871d        3                    1
# ffeb0b1b        3                    3
#
# [5665 rows x 1 columns]

# %%
df1 = feature_engineering.train_df.groupby(['installation_id', 'type'])['event_id'].count().reset_index()

# %%
feature_engineering.comp_train_df.head()
# Out:
#   installation_id  title  accuracy_group  game_time_mean  game_time_sum  \
# 0        0006a69f      3               3    82491.007366      313548319
# 1        0006a69f      0               0    82491.007366      313548319
# 2        0006a69f      3               3    82491.007366      313548319
# 3        0006a69f      3               2    82491.007366      313548319
# 4        0006a69f      0               3    82491.007366      313548319
#
#    game_time_min  game_time_max  game_time_std  game_time_skew  Activity  ...  \
# 0              0        1520600  159789.192183        7.504204    1771.0  ...
# 1              0        1520600  159789.192183        7.504204    1771.0  ...
# 2              0        1520600  159789.192183        7.504204    1771.0  ...
# 3              0        1520600  159789.192183        7.504204    1771.0  ...
# 4              0        1520600  159789.192183        7.504204    1771.0  ...
#
#    (game_time, skew, NONE)  (game_time, skew, TREETOPCITY)  \
# 0                      0.0                        5.704184
# 1                      0.0                        5.704184
# 2                      0.0                        5.704184
# 3                      0.0                        5.704184
# 4                      0.0                        5.704184
#
#    (game_time, std, CRYSTALCAVES)  (game_time, std, MAGMAPEAK)  \
# 0                   115847.423107                 57216.164087
# 1                   115847.423107                 57216.164087
# 2                   115847.423107                 57216.164087
# 3                   115847.423107                 57216.164087
# 4                   115847.423107                 57216.164087
#
#    (game_time, std, NONE)  (game_time, std, TREETOPCITY)  \
# 0                     0.0                  217683.232366
# 1                     0.0                  217683.232366
# 2                     0.0                  217683.232366
# 3                     0.0                  217683.232366
# 4                     0.0                  217683.232366
#
#    (game_time, sum, CRYSTALCAVES)  (game_time, sum, MAGMAPEAK)  \
# 0                    6.031041e+07                  121568696.0
# 1                    6.031041e+07                  121568696.0
# 2                    6.031041e+07                  121568696.0
# 3                    6.031041e+07                  121568696.0
# 4                    6.031041e+07                  121568696.0
#
#    (game_time, sum, NONE)  (game_time, sum, TREETOPCITY)
# 0                     0.0                    191979623.0
# 1                     0.0                    191979623.0
# 2                     0.0                    191979623.0
# 3                     0.0                    191979623.0
# 4                     0.0                    191979623.0
#
# [5 rows x 65 columns]

# %%
feature_engineering.comp_test_df.head()
# Out:
#                  game_time_mean  game_time_sum  game_time_min  game_time_max  \
# installation_id
# 00abaee7           63567.408986       55176511              0        1960630
# 01242218           75770.044869      206018752              0         317027
# 017c5718           33017.233333        4952585              0          60943
# 01a44906           41162.901709        9632119              0          85983
# 01bc6cb6          147664.880252      140576966              0         511237
#
#                  game_time_std  game_time_skew  Activity  Assessment  Clip  \
# installation_id
# 00abaee7         149911.784066       11.578484     454.0        27.0  14.0
# 01242218          61789.322138        1.421303    1356.0       245.0  29.0
# 017c5718          17140.293312       -0.421696     143.0         1.0   6.0
# 01a44906          28696.300044        0.231737     145.0         1.0  10.0
# 01bc6cb6         128478.809653        1.250042     226.0         1.0  17.0
#
#                    Game  ...  (game_time, skew, TREETOPCITY)  \
# installation_id          ...
# 00abaee7          373.0  ...                        8.243170
# 01242218         1089.0  ...                        0.680239
# 017c5718            0.0  ...                       -0.430958
# 01a44906           78.0  ...                        0.222744
# 01bc6cb6          708.0  ...                        0.298199
#
#                  (game_time, std, CRYSTALCAVES)  (game_time, std, MAGMAPEAK)  \
# installation_id
# 00abaee7                           37649.869386                 53238.970991
# 01242218                           67990.867851                 68507.373099
# 017c5718                           75616.844935                143236.743283
# 01a44906                           75616.844935                143236.743283
# 01bc6cb6                           52164.580560                     0.000000
#
#                  (game_time, std, NONE)  (game_time, std, TREETOPCITY)  \
# installation_id
# 00abaee7                            0.0                  222474.449033
# 01242218                            0.0                   45265.064084
# 017c5718                            0.0                   16462.002358
# 01a44906                            0.0                   28492.647474
# 01bc6cb6                            0.0                  155679.905961
#
#                  (game_time, sum, CRYSTALCAVES)  (game_time, sum, MAGMAPEAK)  \
# installation_id
# 00abaee7                           1.381808e+07                 1.675591e+07
# 01242218                           7.183540e+07                 7.283158e+07
# 017c5718                           5.277859e+07                 1.391002e+08
# 01a44906                           5.277859e+07                 1.391002e+08
# 01bc6cb6                           4.737604e+07                 0.000000e+00
#
#                  (game_time, sum, NONE)  (game_time, sum, TREETOPCITY)  title
# installation_id
# 00abaee7                            0.0                     24602523.0      3
# 01242218                            0.0                     61351776.0      3
# 017c5718                            0.0                      4952585.0      3
# 01a44906                            0.0                      9632119.0      3
# 01bc6cb6                            0.0                     93200925.0      3
#
# [5 rows x 63 columns]

# %%
df1.pivot_table(index = 'installation_id', columns = ['type'], values = 'event_id')
# Out:
# type             Activity  Assessment  Clip    Game
# installation_id
# 0001e90f            469.0         NaN   5.0   883.0
# 000447c4             54.0         NaN   3.0   124.0
# 0006a69f           1771.0       261.0  37.0  1732.0
# 0006c192           1206.0       343.0  32.0   643.0
# 0009a5a9            223.0         NaN   4.0   185.0
# ...                   ...         ...   ...     ...
# fff64664            198.0         NaN  25.0   556.0
# fff70c1e              NaN         NaN   4.0    40.0
# fff744ce              NaN         NaN   3.0     NaN
# fff944d5            168.0         NaN   5.0     NaN
# fffc0583             39.0         NaN  13.0   199.0
#
# [17000 rows x 4 columns]

# %%
df_installation_id_type = train_df.groupby(['installation_id', 'type']).agg({'game_time': ['mean', 'sum', 'min', 'max', 'std', 'skew']}).reset_index()
df_pivoted = df_installation_id_type.pivot_table(index = 'installation_id', columns = ['type'], values = [col for col in df_installation_id_type.columns if col not in ['installation_id', 'type']])
# Out:
# /opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/pandas/core/generic.py:3946: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   new_axis = axis.drop(labels, errors=errors)

# %%
df_installation_id_type
# Out:
#       installation_id      type      game_time                         \
#                                           mean        sum min     max
# 0            0001e90f  Activity   63367.074627   29719158   0  194335
# 1            0001e90f      Clip       0.000000          0   0       0
# 2            0001e90f      Game  276451.739524  244106886   0  570396
# 3            000447c4  Activity   57105.851852    3083716   0  102360
# 4            000447c4      Clip       0.000000          0   0       0
# ...               ...       ...            ...        ...  ..     ...
# 40323        fff944d5  Activity   35421.434524    5950801   0   84885
# 40324        fff944d5      Clip       0.000000          0   0       0
# 40325        fffc0583  Activity   19028.076923     742095   0   40473
# 40326        fffc0583      Clip       0.000000          0   0       0
# 40327        fffc0583      Game   41104.658291    8179827   0  124887
#
#
#                  std      skew
# 0       46414.227733  1.098149
# 1           0.000000  0.000000
# 2      156196.423396  0.136662
# 3       30331.063784 -0.250710
# 4           0.000000  0.000000
# ...              ...       ...
# 40323   20988.152604  0.361745
# 40324       0.000000  0.000000
# 40325   11874.329119  0.090608
# 40326       0.000000  0.000000
# 40327   30076.622080  1.239384
#
# [40328 rows x 8 columns]

# %%
df_pivoted
# Out:
#                  game_time                                            \
#                        max                                      mean
# type              Activity Assessment Clip       Game       Activity
# installation_id
# 0001e90f          194335.0        NaN  0.0   570396.0   63367.074627
# 000447c4          102360.0        NaN  0.0   175347.0   57105.851852
# 0006a69f         1520600.0    92799.0  0.0   232249.0  104714.852626
# 0006c192          395901.0   216374.0  0.0   162878.0  104420.986733
# 0009a5a9           96535.0        NaN  0.0  1684228.0   44637.201794
# ...                    ...        ...  ...        ...            ...
# fff64664           77662.0        NaN  0.0  1548496.0   30007.090909
# fff70c1e               NaN        NaN  0.0   152279.0            NaN
# fff744ce               NaN        NaN  0.0        NaN            NaN
# fff944d5           84885.0        NaN  0.0        NaN   35421.434524
# fffc0583           40473.0        NaN  0.0   124887.0   19028.076923
#
#                                                                        ...  \
#                                                        min             ...
# type               Assessment Clip           Game Activity Assessment  ...
# installation_id                                                        ...
# 0001e90f                  NaN  0.0  276451.739524      0.0        NaN  ...
# 000447c4                  NaN  0.0   93382.346774      0.0        NaN  ...
# 0006a69f         24886.245211  0.0   70209.587182      0.0        0.0  ...
# 0006c192         78984.860058  0.0   74684.945568      0.0        0.0  ...
# 0009a5a9                  NaN  0.0  833872.670270      0.0        NaN  ...
# ...                       ...  ...            ...      ...        ...  ...
# fff64664                  NaN  0.0  712558.733813      0.0        NaN  ...
# fff70c1e                  NaN  0.0   90712.400000      NaN        NaN  ...
# fff744ce                  NaN  0.0            NaN      NaN        NaN  ...
# fff944d5                  NaN  0.0            NaN      0.0        NaN  ...
# fffc0583                  NaN  0.0   41104.658291      0.0        NaN  ...
#
#                                                                   \
#                 skew                      std
# type            Clip      Game       Activity    Assessment Clip
# installation_id
# 0001e90f         0.0  0.136662   46414.227733           NaN  0.0
# 000447c4         0.0 -0.193808   30331.063784           NaN  0.0
# 0006a69f         0.0  0.864883  225262.351712  23754.712897  0.0
# 0006c192         0.0  0.153155   91438.772806  66753.552768  0.0
# 0009a5a9         0.0 -0.011412   26599.097575           NaN  0.0
# ...              ...       ...            ...           ...  ...
# fff64664         0.0  0.095065   20570.679254           NaN  0.0
# fff70c1e         0.0 -0.402845            NaN           NaN  0.0
# fff744ce         0.0       NaN            NaN           NaN  0.0
# fff944d5         0.0       NaN   20988.152604           NaN  0.0
# fffc0583         0.0  1.239384   11874.329119           NaN  0.0
#
#
#                                         sum
# type                      Game     Activity  Assessment Clip         Game
# installation_id
# 0001e90f         156196.423396   29719158.0         NaN  0.0  244106886.0
# 000447c4          47675.659466    3083716.0         NaN  0.0   11579411.0
# 0006a69f          52702.709458  185450004.0   6495310.0  0.0  121603005.0
# 0006c192          42271.971336  125931710.0  27091807.0  0.0   48022420.0
# 0009a5a9         770552.108203    9954096.0         NaN  0.0  154266444.0
# ...                        ...          ...         ...  ...          ...
# fff64664         583951.268238    5941404.0         NaN  0.0  396182656.0
# fff70c1e          53833.619997          NaN         NaN  0.0    3628496.0
# fff744ce                   NaN          NaN         NaN  0.0          NaN
# fff944d5                   NaN    5950801.0         NaN  0.0          NaN
# fffc0583          30076.622080     742095.0         NaN  0.0    8179827.0
#
# [17000 rows x 24 columns]

# %%
[col for col in df_installation_id_type.columns if col not in ['installation_id', 'type']]
# Out:
# [('installation_id', ''),
#  ('type', ''),
#  ('game_time', 'mean'),
#  ('game_time', 'sum'),
#  ('game_time', 'min'),
#  ('game_time', 'max'),
#  ('game_time', 'std'),
#  ('game_time', 'skew')]

# %%
df_test = feature_engineering.comp_train_df
df_test.columns
# Out:
# Index([                     'game_time_mean',
#                              'game_time_sum',
#                              'game_time_min',
#                              'game_time_max',
#                              'game_time_std',
#                             'game_time_skew',
#                                   'Activity',
#                                 'Assessment',
#                                       'Clip',
#                                       'Game',
#                               'CRYSTALCAVES',
#                                  'MAGMAPEAK',
#                                       'NONE',
#                                'TREETOPCITY',
#             ('game_time', 'max', 'Activity'),
#           ('game_time', 'max', 'Assessment'),
#                 ('game_time', 'max', 'Clip'),
#                 ('game_time', 'max', 'Game'),
#            ('game_time', 'mean', 'Activity'),
#          ('game_time', 'mean', 'Assessment'),
#                ('game_time', 'mean', 'Clip'),
#                ('game_time', 'mean', 'Game'),
#             ('game_time', 'min', 'Activity'),
#           ('game_time', 'min', 'Assessment'),
#                 ('game_time', 'min', 'Clip'),
#                 ('game_time', 'min', 'Game'),
#            ('game_time', 'skew', 'Activity'),
#          ('game_time', 'skew', 'Assessment'),
#                ('game_time', 'skew', 'Clip'),
#                ('game_time', 'skew', 'Game'),
#             ('game_time', 'std', 'Activity'),
#           ('game_time', 'std', 'Assessment'),
#                 ('game_time', 'std', 'Clip'),
#                 ('game_time', 'std', 'Game'),
#             ('game_time', 'sum', 'Activity'),
#           ('game_time', 'sum', 'Assessment'),
#                 ('game_time', 'sum', 'Clip'),
#                 ('game_time', 'sum', 'Game'),
#         ('game_time', 'max', 'CRYSTALCAVES'),
#            ('game_time', 'max', 'MAGMAPEAK'),
#                 ('game_time', 'max', 'NONE'),
#          ('game_time', 'max', 'TREETOPCITY'),
#        ('game_time', 'mean', 'CRYSTALCAVES'),
#           ('game_time', 'mean', 'MAGMAPEAK'),
#                ('game_time', 'mean', 'NONE'),
#         ('game_time', 'mean', 'TREETOPCITY'),
#         ('game_time', 'min', 'CRYSTALCAVES'),
#            ('game_time', 'min', 'MAGMAPEAK'),
#                 ('game_time', 'min', 'NONE'),
#          ('game_time', 'min', 'TREETOPCITY'),
#        ('game_time', 'skew', 'CRYSTALCAVES'),
#           ('game_time', 'skew', 'MAGMAPEAK'),
#                ('game_time', 'skew', 'NONE'),
#         ('game_time', 'skew', 'TREETOPCITY'),
#         ('game_time', 'std', 'CRYSTALCAVES'),
#            ('game_time', 'std', 'MAGMAPEAK'),
#                 ('game_time', 'std', 'NONE'),
#          ('game_time', 'std', 'TREETOPCITY'),
#         ('game_time', 'sum', 'CRYSTALCAVES'),
#            ('game_time', 'sum', 'MAGMAPEAK'),
#                 ('game_time', 'sum', 'NONE'),
#          ('game_time', 'sum', 'TREETOPCITY')],
#       dtype='object')

# %%
train_labels_df
# Out:
#            game_session installation_id                         title  \
# 0      6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1      77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2      901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3      9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4      a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
# ...                 ...             ...                           ...
# 17685  c996482b11d149dd        ffc90c32    Bird Measurer (Assessment)
# 17686  b05a02b52d5c1f4c        ffd2871d  Cauldron Filler (Assessment)
# 17687  5448d652309a6324        ffeb0b1b  Cauldron Filler (Assessment)
# 17688  a6885ab824fbc32c        ffeb0b1b  Mushroom Sorter (Assessment)
# 17689  dadd1a4d8ac68ab0        ffeb0b1b  Cauldron Filler (Assessment)
#
#        num_correct  num_incorrect  accuracy  accuracy_group
# 0                1              0  1.000000               3
# 1                0             11  0.000000               0
# 2                1              0  1.000000               3
# 3                1              1  0.500000               2
# 4                1              0  1.000000               3
# ...            ...            ...       ...             ...
# 17685            1              0  1.000000               3
# 17686            1              0  1.000000               3
# 17687            1              2  0.333333               1
# 17688            0              1  0.000000               0
# 17689            1              2  0.333333               1
#
# [17690 rows x 7 columns]

# %%
train_labels_df.groupby('title').mean()[['accuracy']]
# Out:
#                               accuracy
# title
# Bird Measurer (Assessment)    0.387379
# Cart Balancer (Assessment)    0.742232
# Cauldron Filler (Assessment)  0.735537
# Chest Sorter (Assessment)     0.248625
# Mushroom Sorter (Assessment)  0.711042

# %%
game_session = train_labels_df.groupby('game_session')['installation_id'].size()
game_session[game_session > 1]
# Out:
# Series([], Name: installation_id, dtype: int64)

# %%
train_labels_df.groupby('title')['accuracy_group'].agg(lambda x:x.value_counts().index[0])
# Out:
# title
# Bird Measurer (Assessment)      0
# Cart Balancer (Assessment)      3
# Cauldron Filler (Assessment)    3
# Chest Sorter (Assessment)       0
# Mushroom Sorter (Assessment)    3
# Name: accuracy_group, dtype: int64

# %%
train_labels_df.groupby('title').median()[['accuracy_group']]
# Out:
#                               accuracy_group
# title
# Bird Measurer (Assessment)                 1
# Cart Balancer (Assessment)                 3
# Cauldron Filler (Assessment)               3
# Chest Sorter (Assessment)                  0
# Mushroom Sorter (Assessment)               3

# %%
train_labels_df.groupby('title')['accuracy_group'].agg(lambda x:x.value_counts().index[1])
# Out:
# title
# Bird Measurer (Assessment)      1
# Cart Balancer (Assessment)      0
# Cauldron Filler (Assessment)    2
# Chest Sorter (Assessment)       3
# Mushroom Sorter (Assessment)    0
# Name: accuracy_group, dtype: int64

# %%
labels_map = dict(train_labels_df.groupby('title')['accuracy_group'].agg(lambda x:x.value_counts().index[0]))

# %%
labels_map
# Out:
# {'Bird Measurer (Assessment)': 0,
#  'Cart Balancer (Assessment)': 3,
#  'Cauldron Filler (Assessment)': 3,
#  'Chest Sorter (Assessment)': 0,
#  'Mushroom Sorter (Assessment)': 3}

# %%
labels = train_labels_df[['installation_id', 'title', 'accuracy_group']]

# %%
labels['title'] = labels['title'].map(labels_map)
# Out:
# /opt/anaconda3/envs/deeplearning/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
labels
# Out:
#       installation_id  title  accuracy_group
# 0            0006a69f      3               3
# 1            0006a69f      0               0
# 2            0006a69f      3               3
# 3            0006a69f      3               2
# 4            0006a69f      0               3
# ...               ...    ...             ...
# 17685        ffc90c32      0               3
# 17686        ffd2871d      3               3
# 17687        ffeb0b1b      3               1
# 17688        ffeb0b1b      3               0
# 17689        ffeb0b1b      3               1
#
# [17690 rows x 3 columns]

# %%
grouped_test = test_df.groupby('installation_id').last()['title'].map(labels_map)

# %%
feature_engineering.comp_test_df['title'] = grouped_test.reset_index(drop=True).values

# %%
feature_engineering.comp_test_df
# Out:
#                  game_time_mean  game_time_sum  game_time_min  game_time_max  \
# installation_id
# 00abaee7           63567.408986       55176511              0        1960630
# 01242218           75770.044869      206018752              0         317027
# 017c5718           33017.233333        4952585              0          60943
# 01a44906           41162.901709        9632119              0          85983
# 01bc6cb6          147664.880252      140576966              0         511237
# ...                         ...            ...            ...            ...
# fee254cf           56850.495283       12052305              0         155008
# ff57e602           44772.023102       13565923              0         139394
# ffc73fb2           61802.442966       32508085              0         199825
# ffe00ca8           25213.420849        6530276              0          72242
# ffe774cc           13978.311111         629024              0          36607
#
#                  game_time_std  game_time_skew  Activity  Assessment  Clip  \
# installation_id
# 00abaee7         149911.784066       11.578484     454.0        27.0  14.0
# 01242218          61789.322138        1.421303    1356.0       245.0  29.0
# 017c5718          17140.293312       -0.421696     143.0         1.0   6.0
# 01a44906          28696.300044        0.231737     145.0         1.0  10.0
# 01bc6cb6         128478.809653        1.250042     226.0         1.0  17.0
# ...                        ...             ...       ...         ...   ...
# fee254cf          43941.426092        0.454220       0.0       116.0   4.0
# ff57e602          31785.997875        0.699889     127.0        29.0  11.0
# ffc73fb2          53869.630318        0.728098     238.0       256.0  32.0
# ffe00ca8          20859.265204        0.705400     123.0       110.0  11.0
# ffe774cc          10543.739687        0.406577       0.0        42.0   3.0
#
#                    Game  ...  (game_time, skew, TREETOPCITY)  \
# installation_id          ...
# 00abaee7          373.0  ...                        8.243170
# 01242218         1089.0  ...                        0.680239
# 017c5718            0.0  ...                       -0.430958
# 01a44906           78.0  ...                        0.222744
# 01bc6cb6          708.0  ...                        0.298199
# ...                 ...  ...                             ...
# fee254cf           92.0  ...                        0.446872
# ff57e602          136.0  ...                       -0.158853
# ffc73fb2            0.0  ...                        0.433389
# ffe00ca8           15.0  ...                       -0.201029
# ffe774cc            0.0  ...                        0.406577
#
#                  (game_time, std, CRYSTALCAVES)  (game_time, std, MAGMAPEAK)  \
# installation_id
# 00abaee7                           37649.869386                 53238.970991
# 01242218                           67990.867851                 68507.373099
# 017c5718                           75616.844935                143236.743283
# 01a44906                           75616.844935                143236.743283
# 01bc6cb6                           52164.580560                     0.000000
# ...                                         ...                          ...
# fee254cf                           75616.844935                143236.743283
# ff57e602                           33037.671890                143236.743283
# ffc73fb2                           52554.796817                 15886.543489
# ffe00ca8                               0.000000                 11511.482848
# ffe774cc                           75616.844935                143236.743283
#
#                  (game_time, std, NONE)  (game_time, std, TREETOPCITY)  \
# installation_id
# 00abaee7                            0.0                  222474.449033
# 01242218                            0.0                   45265.064084
# 017c5718                            0.0                   16462.002358
# 01a44906                            0.0                   28492.647474
# 01bc6cb6                            0.0                  155679.905961
# ...                                 ...                            ...
# fee254cf                            0.0                   43796.157031
# ff57e602                            0.0                   18885.540724
# ffc73fb2                            0.0                   57100.791765
# ffe00ca8                            0.0                   22603.416385
# ffe774cc                            0.0                   10543.739687
#
#                  (game_time, sum, CRYSTALCAVES)  (game_time, sum, MAGMAPEAK)  \
# installation_id
# 00abaee7                           1.381808e+07                 1.675591e+07
# 01242218                           7.183540e+07                 7.283158e+07
# 017c5718                           5.277859e+07                 1.391002e+08
# 01a44906                           5.277859e+07                 1.391002e+08
# 01bc6cb6                           4.737604e+07                 0.000000e+00
# ...                                         ...                          ...
# fee254cf                           5.277859e+07                 0.000000e+00
# ff57e602                           1.190693e+07                 1.391002e+08
# ffc73fb2                           1.126947e+07                 2.850762e+06
# ffe00ca8                           0.000000e+00                 2.164721e+06
# ffe774cc                           5.277859e+07                 1.391002e+08
#
#                  (game_time, sum, NONE)  (game_time, sum, TREETOPCITY)  title
# installation_id
# 00abaee7                            0.0                     24602523.0      3
# 01242218                            0.0                     61351776.0      3
# 017c5718                            0.0                      4952585.0      3
# 01a44906                            0.0                      9632119.0      3
# 01bc6cb6                            0.0                     93200925.0      3
# ...                                 ...                            ...    ...
# fee254cf                            0.0                     12052305.0      3
# ff57e602                            0.0                      1658996.0      0
# ffc73fb2                            0.0                     18387852.0      3
# ffe00ca8                            0.0                      4365555.0      3
# ffe774cc                            0.0                       629024.0      0
#
# [1000 rows x 63 columns]

# %%
# Out:
# (1156414, 20)
